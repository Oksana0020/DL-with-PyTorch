# %% [markdown]
# <a href="https://colab.research.google.com/github/Oksana0020/DL-with-PyTorch/blob/main/Lab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TASK 1: Data Preparation

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer

# %%
from datasets import load_dataset

dataset = load_dataset("imdb")

train_texts = dataset["train"]["text"][:2000]
train_labels = dataset["train"]["label"][:2000]

test_texts = dataset["test"]["text"][:500]
test_labels = dataset["test"]["label"][:500]
# Out:
# README.md: 0.00B [00:00, ?B/s]
# plain_text/train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# plain_text/test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# plain_text/unsupervised-00000-of-00001.p(…):   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
# Using a Hugging Face tokenizer for consistency and simplicity
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
max_len = 128 # Reduced max_len for smaller dataset and faster processing

# Text processing function - now uses the Hugging Face tokenizer
def process_text_hf(text, tokenizer, max_len):
    # This will pad and truncate automatically
    encoding = tokenizer(
        text,
        max_length=max_len,
        padding='max_length',
        truncation=True,
        return_tensors='pt'
    )
    return encoding['input_ids'].squeeze(0) # Remove batch dimension

# Custom Dataset
class SimplifiedIMDBDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.data = []
        for text, label in zip(texts, labels):
            text_tensor = process_text_hf(text, self.tokenizer, self.max_len)
            label_tensor = torch.tensor([float(label)], dtype=torch.float)
            self.data.append((text_tensor, label_tensor))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# Create datasets
train_dataset = SimplifiedIMDBDataset(train_texts, train_labels, tokenizer, max_len)
test_dataset = SimplifiedIMDBDataset(test_texts, test_labels, tokenizer, max_len)

# Create dataloaders
batch_size = 2 # Reduced batch size for very small dataset
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

# Determine vocab_size and pad_idx from the Hugging Face tokenizer
# Note: For LSTM, we would typically build a custom vocab if not using pretrained embeddings
# For simplification here, we'll use a large enough vocab size and HF's pad_token_id
vocab_size = tokenizer.vocab_size
pad_idx = tokenizer.pad_token_id

print(f"Vocab size (from HF tokenizer): {vocab_size}")
print(f"Pad token ID (from HF tokenizer): {pad_idx}")
# Out:
# Vocab size (from HF tokenizer): 30522
# Pad token ID (from HF tokenizer): 0

# %% [markdown]
# # TASK 2: LSTM Model (Minor adjustments for new data processing)

# %%
import torch.nn as nn
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class LSTMTextClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers,
                 bidirectional, dropout, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=pad_idx)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=n_layers,
                            bidirectional=bidirectional, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        # text shape: [batch_size, seq_len]
        embedded = self.embedding(text)
        # embedded shape: [batch_size, seq_len, embedding_dim]

        output, (hidden, cell) = self.lstm(embedded)
        # output shape: [batch_size, seq_len, hidden_dim * n_directions]

        if self.lstm.bidirectional:
            # Concatenate the last two hidden states (forward and backward)
            hidden = torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1)
        else:
            hidden = hidden[-1,:,:]
        # hidden shape: [batch_size, hidden_dim * n_directions]

        hidden = self.dropout(hidden)
        return self.fc(hidden)

# Initialize LSTM model
embedding_dim = 100
hidden_dim = 128 # Reduced hidden_dim for smaller model
output_dim = 1
n_layers = 2
bidirectional = True
dropout = 0.5

lstm_model = LSTMTextClassifier(
    vocab_size, embedding_dim, hidden_dim, output_dim,
    n_layers, bidirectional, dropout, pad_idx
).to(device)

# %% [markdown]
# # TASK 3: LSTM Training

# %%
import torch.optim as optim
import time

# %%
optimizer_lstm = optim.Adam(lstm_model.parameters(), lr=0.001)
criterion = nn.BCEWithLogitsLoss()

def train_model(model, dataloader, optimizer, criterion, epochs=3): # Reduced epochs for faster demo
    model.train()
    start_time = time.time()

    epoch_losses = []
    for epoch in range(epochs):
        epoch_loss = 0
        for batch_idx, (text, labels) in enumerate(dataloader):
            text, labels = text.to(device), labels.to(device)

            optimizer.zero_grad()
            predictions = model(text)
            loss = criterion(predictions, labels)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 1 == 0: # Print more frequently for tiny dataset
                print(f"Epoch {epoch+1}/{epochs}, Batch {batch_idx}/{len(dataloader)}, Loss: {loss.item():.4f}")

        avg_epoch_loss = epoch_loss / len(dataloader)
        epoch_losses.append(avg_epoch_loss)
        print(f"Epoch {epoch+1}/{epochs}, Average Loss: {avg_epoch_loss:.4f}")

    training_time = time.time() - start_time
    print(f"Training completed in {training_time:.2f} seconds")

    return epoch_losses, training_time

def evaluate_model(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    start_time = time.time()

    with torch.no_grad():
        for text, labels in dataloader:
            text, labels = text.to(device), labels.to(device)
            outputs = model(text)
            predicted = (torch.sigmoid(outputs) > 0.5).float()
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    inference_time = time.time() - start_time
    accuracy = 100 * correct / total

    print(f"Accuracy: {accuracy:.2f}%")
    print(f"Inference time: {inference_time:.2f} seconds")

    return accuracy, inference_time

# Train and evaluate LSTM
print("\n--- Training LSTM Model ---")
lstm_losses, lstm_train_time = train_model(lstm_model, train_dataloader, optimizer_lstm, criterion, epochs=3)
print("\n--- Evaluating LSTM Model ---")
lstm_accuracy, lstm_inference_time = evaluate_model(lstm_model, test_dataloader)
# Out:
# --- Training LSTM Model ---
# Epoch 1/3, Batch 0/1000, Loss: 0.6929
# Epoch 1/3, Batch 1/1000, Loss: 0.6476
# Epoch 1/3, Batch 2/1000, Loss: 0.6210
# Epoch 1/3, Batch 3/1000, Loss: 0.5597
# Epoch 1/3, Batch 4/1000, Loss: 0.5362
# Epoch 1/3, Batch 5/1000, Loss: 0.5236
# Epoch 1/3, Batch 6/1000, Loss: 0.4344
# Epoch 1/3, Batch 7/1000, Loss: 0.4593
# Epoch 1/3, Batch 8/1000, Loss: 0.3176
# Epoch 1/3, Batch 9/1000, Loss: 0.3197
# Epoch 1/3, Batch 10/1000, Loss: 0.2487
# Epoch 1/3, Batch 11/1000, Loss: 0.2003
# Epoch 1/3, Batch 12/1000, Loss: 0.1275
# Epoch 1/3, Batch 13/1000, Loss: 0.1352
# Epoch 1/3, Batch 14/1000, Loss: 0.1230
# Epoch 1/3, Batch 15/1000, Loss: 0.0435
# Epoch 1/3, Batch 16/1000, Loss: 0.0203
# Epoch 1/3, Batch 17/1000, Loss: 0.0086
# Epoch 1/3, Batch 18/1000, Loss: 0.0109
# Epoch 1/3, Batch 19/1000, Loss: 0.0044
# Epoch 1/3, Batch 20/1000, Loss: 0.0033
# Epoch 1/3, Batch 21/1000, Loss: 0.0032
# Epoch 1/3, Batch 22/1000, Loss: 0.0020
# Epoch 1/3, Batch 23/1000, Loss: 0.0015
# Epoch 1/3, Batch 24/1000, Loss: 0.0014
# Epoch 1/3, Batch 25/1000, Loss: 0.0005
# Epoch 1/3, Batch 26/1000, Loss: 0.0004
# Epoch 1/3, Batch 27/1000, Loss: 0.0007
# Epoch 1/3, Batch 28/1000, Loss: 0.0012
# Epoch 1/3, Batch 29/1000, Loss: 0.0005
# Epoch 1/3, Batch 30/1000, Loss: 0.0002
# Epoch 1/3, Batch 31/1000, Loss: 0.0002
# Epoch 1/3, Batch 32/1000, Loss: 0.0004
# Epoch 1/3, Batch 33/1000, Loss: 0.0001
# Epoch 1/3, Batch 34/1000, Loss: 0.0002
# Epoch 1/3, Batch 35/1000, Loss: 0.0002
# Epoch 1/3, Batch 36/1000, Loss: 0.0001
# Epoch 1/3, Batch 37/1000, Loss: 0.0001
# Epoch 1/3, Batch 38/1000, Loss: 0.0001
# Epoch 1/3, Batch 39/1000, Loss: 0.0001
# Epoch 1/3, Batch 40/1000, Loss: 0.0001
# Epoch 1/3, Batch 41/1000, Loss: 0.0001
# Epoch 1/3, Batch 42/1000, Loss: 0.0002
# Epoch 1/3, Batch 43/1000, Loss: 0.0001
# Epoch 1/3, Batch 44/1000, Loss: 0.0001
# Epoch 1/3, Batch 45/1000, Loss: 0.0003
# Epoch 1/3, Batch 46/1000, Loss: 0.0001
# Epoch 1/3, Batch 47/1000, Loss: 0.0001
# Epoch 1/3, Batch 48/1000, Loss: 0.0002
# Epoch 1/3, Batch 49/1000, Loss: 0.0000
# Epoch 1/3, Batch 50/1000, Loss: 0.0002
# Epoch 1/3, Batch 51/1000, Loss: 0.0001
# Epoch 1/3, Batch 52/1000, Loss: 0.0001
# Epoch 1/3, Batch 53/1000, Loss: 0.0001
# Epoch 1/3, Batch 54/1000, Loss: 0.0002
# Epoch 1/3, Batch 55/1000, Loss: 0.0001
# Epoch 1/3, Batch 56/1000, Loss: 0.0000
# Epoch 1/3, Batch 57/1000, Loss: 0.0000
# Epoch 1/3, Batch 58/1000, Loss: 0.0000
# Epoch 1/3, Batch 59/1000, Loss: 0.0001
# Epoch 1/3, Batch 60/1000, Loss: 0.0001
# Epoch 1/3, Batch 61/1000, Loss: 0.0001
# Epoch 1/3, Batch 62/1000, Loss: 0.0001
# Epoch 1/3, Batch 63/1000, Loss: 0.0001
# Epoch 1/3, Batch 64/1000, Loss: 0.0000
# Epoch 1/3, Batch 65/1000, Loss: 0.0001
# Epoch 1/3, Batch 66/1000, Loss: 0.0001
# Epoch 1/3, Batch 67/1000, Loss: 0.0001
# Epoch 1/3, Batch 68/1000, Loss: 0.0001
# Epoch 1/3, Batch 69/1000, Loss: 0.0001
# Epoch 1/3, Batch 70/1000, Loss: 0.0001
# Epoch 1/3, Batch 71/1000, Loss: 0.0001
# Epoch 1/3, Batch 72/1000, Loss: 0.0001
# Epoch 1/3, Batch 73/1000, Loss: 0.0001
# Epoch 1/3, Batch 74/1000, Loss: 0.0002
# Epoch 1/3, Batch 75/1000, Loss: 0.0001
# Epoch 1/3, Batch 76/1000, Loss: 0.0002
# Epoch 1/3, Batch 77/1000, Loss: 0.0002
# Epoch 1/3, Batch 78/1000, Loss: 0.0001
# Epoch 1/3, Batch 79/1000, Loss: 0.0001
# Epoch 1/3, Batch 80/1000, Loss: 0.0000
# Epoch 1/3, Batch 81/1000, Loss: 0.0001
# Epoch 1/3, Batch 82/1000, Loss: 0.0001
# Epoch 1/3, Batch 83/1000, Loss: 0.0000
# Epoch 1/3, Batch 84/1000, Loss: 0.0001
# Epoch 1/3, Batch 85/1000, Loss: 0.0001
# Epoch 1/3, Batch 86/1000, Loss: 0.0001
# Epoch 1/3, Batch 87/1000, Loss: 0.0002
# Epoch 1/3, Batch 88/1000, Loss: 0.0000
# Epoch 1/3, Batch 89/1000, Loss: 0.0000
# Epoch 1/3, Batch 90/1000, Loss: 0.0001
# Epoch 1/3, Batch 91/1000, Loss: 0.0001
# Epoch 1/3, Batch 92/1000, Loss: 0.0001
# Epoch 1/3, Batch 93/1000, Loss: 0.0001
# Epoch 1/3, Batch 94/1000, Loss: 0.0001
# Epoch 1/3, Batch 95/1000, Loss: 0.0001
# Epoch 1/3, Batch 96/1000, Loss: 0.0000
# Epoch 1/3, Batch 97/1000, Loss: 0.0001
# Epoch 1/3, Batch 98/1000, Loss: 0.0000
# Epoch 1/3, Batch 99/1000, Loss: 0.0001
# Epoch 1/3, Batch 100/1000, Loss: 0.0001
# Epoch 1/3, Batch 101/1000, Loss: 0.0001
# Epoch 1/3, Batch 102/1000, Loss: 0.0000
# Epoch 1/3, Batch 103/1000, Loss: 0.0001
# Epoch 1/3, Batch 104/1000, Loss: 0.0001
# Epoch 1/3, Batch 105/1000, Loss: 0.0001
# Epoch 1/3, Batch 106/1000, Loss: 0.0001
# Epoch 1/3, Batch 107/1000, Loss: 0.0000
# Epoch 1/3, Batch 108/1000, Loss: 0.0001
# Epoch 1/3, Batch 109/1000, Loss: 0.0000
# Epoch 1/3, Batch 110/1000, Loss: 0.0001
# Epoch 1/3, Batch 111/1000, Loss: 0.0001
# Epoch 1/3, Batch 112/1000, Loss: 0.0001
# Epoch 1/3, Batch 113/1000, Loss: 0.0001
# Epoch 1/3, Batch 114/1000, Loss: 0.0001
# Epoch 1/3, Batch 115/1000, Loss: 0.0002
# Epoch 1/3, Batch 116/1000, Loss: 0.0001
# Epoch 1/3, Batch 117/1000, Loss: 0.0001
# Epoch 1/3, Batch 118/1000, Loss: 0.0001
# Epoch 1/3, Batch 119/1000, Loss: 0.0000
# Epoch 1/3, Batch 120/1000, Loss: 0.0004
# Epoch 1/3, Batch 121/1000, Loss: 0.0002
# Epoch 1/3, Batch 122/1000, Loss: 0.0002
# Epoch 1/3, Batch 123/1000, Loss: 0.0001
# Epoch 1/3, Batch 124/1000, Loss: 0.0000
# Epoch 1/3, Batch 125/1000, Loss: 0.0001
# Epoch 1/3, Batch 126/1000, Loss: 0.0001
# Epoch 1/3, Batch 127/1000, Loss: 0.0001
# Epoch 1/3, Batch 128/1000, Loss: 0.0001
# Epoch 1/3, Batch 129/1000, Loss: 0.0001
# Epoch 1/3, Batch 130/1000, Loss: 0.0001
# Epoch 1/3, Batch 131/1000, Loss: 0.0000
# Epoch 1/3, Batch 132/1000, Loss: 0.0001
# Epoch 1/3, Batch 133/1000, Loss: 0.0001
# Epoch 1/3, Batch 134/1000, Loss: 0.0001
# Epoch 1/3, Batch 135/1000, Loss: 0.0001
# Epoch 1/3, Batch 136/1000, Loss: 0.0001
# Epoch 1/3, Batch 137/1000, Loss: 0.0001
# Epoch 1/3, Batch 138/1000, Loss: 0.0000
# Epoch 1/3, Batch 139/1000, Loss: 0.0001
# Epoch 1/3, Batch 140/1000, Loss: 0.0002
# Epoch 1/3, Batch 141/1000, Loss: 0.0001
# Epoch 1/3, Batch 142/1000, Loss: 0.0001
# Epoch 1/3, Batch 143/1000, Loss: 0.0001
# Epoch 1/3, Batch 144/1000, Loss: 0.0001
# Epoch 1/3, Batch 145/1000, Loss: 0.0001
# Epoch 1/3, Batch 146/1000, Loss: 0.0000
# Epoch 1/3, Batch 147/1000, Loss: 0.0001
# Epoch 1/3, Batch 148/1000, Loss: 0.0001
# Epoch 1/3, Batch 149/1000, Loss: 0.0001
# Epoch 1/3, Batch 150/1000, Loss: 0.0000
# Epoch 1/3, Batch 151/1000, Loss: 0.0000
# Epoch 1/3, Batch 152/1000, Loss: 0.0000
# Epoch 1/3, Batch 153/1000, Loss: 0.0001
# Epoch 1/3, Batch 154/1000, Loss: 0.0001
# Epoch 1/3, Batch 155/1000, Loss: 0.0000
# Epoch 1/3, Batch 156/1000, Loss: 0.0001
# Epoch 1/3, Batch 157/1000, Loss: 0.0000
# Epoch 1/3, Batch 158/1000, Loss: 0.0001
# Epoch 1/3, Batch 159/1000, Loss: 0.0000
# Epoch 1/3, Batch 160/1000, Loss: 0.0001
# Epoch 1/3, Batch 161/1000, Loss: 0.0002
# Epoch 1/3, Batch 162/1000, Loss: 0.0001
# Epoch 1/3, Batch 163/1000, Loss: 0.0001
# Epoch 1/3, Batch 164/1000, Loss: 0.0001
# Epoch 1/3, Batch 165/1000, Loss: 0.0001
# Epoch 1/3, Batch 166/1000, Loss: 0.0000
# Epoch 1/3, Batch 167/1000, Loss: 0.0001
# Epoch 1/3, Batch 168/1000, Loss: 0.0001
# Epoch 1/3, Batch 169/1000, Loss: 0.0001
# Epoch 1/3, Batch 170/1000, Loss: 0.0001
# Epoch 1/3, Batch 171/1000, Loss: 0.0001
# Epoch 1/3, Batch 172/1000, Loss: 0.0001
# Epoch 1/3, Batch 173/1000, Loss: 0.0001
# Epoch 1/3, Batch 174/1000, Loss: 0.0000
# Epoch 1/3, Batch 175/1000, Loss: 0.0000
# Epoch 1/3, Batch 176/1000, Loss: 0.0001
# Epoch 1/3, Batch 177/1000, Loss: 0.0001
# Epoch 1/3, Batch 178/1000, Loss: 0.0001
# Epoch 1/3, Batch 179/1000, Loss: 0.0001
# Epoch 1/3, Batch 180/1000, Loss: 0.0001
# Epoch 1/3, Batch 181/1000, Loss: 0.0000
# Epoch 1/3, Batch 182/1000, Loss: 0.0001
# Epoch 1/3, Batch 183/1000, Loss: 0.0001
# Epoch 1/3, Batch 184/1000, Loss: 0.0000
# Epoch 1/3, Batch 185/1000, Loss: 0.0001
# Epoch 1/3, Batch 186/1000, Loss: 0.0001
# Epoch 1/3, Batch 187/1000, Loss: 0.0001
# Epoch 1/3, Batch 188/1000, Loss: 0.0001
# Epoch 1/3, Batch 189/1000, Loss: 0.0001
# Epoch 1/3, Batch 190/1000, Loss: 0.0000
# Epoch 1/3, Batch 191/1000, Loss: 0.0001
# Epoch 1/3, Batch 192/1000, Loss: 0.0001
# Epoch 1/3, Batch 193/1000, Loss: 0.0001
# Epoch 1/3, Batch 194/1000, Loss: 0.0000
# Epoch 1/3, Batch 195/1000, Loss: 0.0000
# Epoch 1/3, Batch 196/1000, Loss: 0.0001
# Epoch 1/3, Batch 197/1000, Loss: 0.0001
# Epoch 1/3, Batch 198/1000, Loss: 0.0000
# Epoch 1/3, Batch 199/1000, Loss: 0.0001
# Epoch 1/3, Batch 200/1000, Loss: 0.0001
# Epoch 1/3, Batch 201/1000, Loss: 0.0001
# Epoch 1/3, Batch 202/1000, Loss: 0.0001
# Epoch 1/3, Batch 203/1000, Loss: 0.0000
# Epoch 1/3, Batch 204/1000, Loss: 0.0000
# Epoch 1/3, Batch 205/1000, Loss: 0.0000
# Epoch 1/3, Batch 206/1000, Loss: 0.0002
# Epoch 1/3, Batch 207/1000, Loss: 0.0001
# Epoch 1/3, Batch 208/1000, Loss: 0.0000
# Epoch 1/3, Batch 209/1000, Loss: 0.0000
# Epoch 1/3, Batch 210/1000, Loss: 0.0001
# Epoch 1/3, Batch 211/1000, Loss: 0.0001
# Epoch 1/3, Batch 212/1000, Loss: 0.0000
# Epoch 1/3, Batch 213/1000, Loss: 0.0002
# Epoch 1/3, Batch 214/1000, Loss: 0.0000
# Epoch 1/3, Batch 215/1000, Loss: 0.0001
# Epoch 1/3, Batch 216/1000, Loss: 0.0000
# Epoch 1/3, Batch 217/1000, Loss: 0.0002
# Epoch 1/3, Batch 218/1000, Loss: 0.0000
# Epoch 1/3, Batch 219/1000, Loss: 0.0000
# Epoch 1/3, Batch 220/1000, Loss: 0.0000
# Epoch 1/3, Batch 221/1000, Loss: 0.0000
# Epoch 1/3, Batch 222/1000, Loss: 0.0001
# Epoch 1/3, Batch 223/1000, Loss: 0.0000
# Epoch 1/3, Batch 224/1000, Loss: 0.0000
# Epoch 1/3, Batch 225/1000, Loss: 0.0001
# Epoch 1/3, Batch 226/1000, Loss: 0.0001
# Epoch 1/3, Batch 227/1000, Loss: 0.0000
# Epoch 1/3, Batch 228/1000, Loss: 0.0001
# Epoch 1/3, Batch 229/1000, Loss: 0.0000
# Epoch 1/3, Batch 230/1000, Loss: 0.0001
# Epoch 1/3, Batch 231/1000, Loss: 0.0001
# Epoch 1/3, Batch 232/1000, Loss: 0.0000
# Epoch 1/3, Batch 233/1000, Loss: 0.0000
# Epoch 1/3, Batch 234/1000, Loss: 0.0000
# Epoch 1/3, Batch 235/1000, Loss: 0.0000
# Epoch 1/3, Batch 236/1000, Loss: 0.0001
# Epoch 1/3, Batch 237/1000, Loss: 0.0000
# Epoch 1/3, Batch 238/1000, Loss: 0.0000
# Epoch 1/3, Batch 239/1000, Loss: 0.0000
# Epoch 1/3, Batch 240/1000, Loss: 0.0000
# Epoch 1/3, Batch 241/1000, Loss: 0.0001
# Epoch 1/3, Batch 242/1000, Loss: 0.0000
# Epoch 1/3, Batch 243/1000, Loss: 0.0000
# Epoch 1/3, Batch 244/1000, Loss: 0.0001
# Epoch 1/3, Batch 245/1000, Loss: 0.0000
# Epoch 1/3, Batch 246/1000, Loss: 0.0000
# Epoch 1/3, Batch 247/1000, Loss: 0.0000
# Epoch 1/3, Batch 248/1000, Loss: 0.0000
# Epoch 1/3, Batch 249/1000, Loss: 0.0000
# Epoch 1/3, Batch 250/1000, Loss: 0.0000
# Epoch 1/3, Batch 251/1000, Loss: 0.0000
# Epoch 1/3, Batch 252/1000, Loss: 0.0000
# Epoch 1/3, Batch 253/1000, Loss: 0.0000
# Epoch 1/3, Batch 254/1000, Loss: 0.0001
# Epoch 1/3, Batch 255/1000, Loss: 0.0000
# Epoch 1/3, Batch 256/1000, Loss: 0.0001
# Epoch 1/3, Batch 257/1000, Loss: 0.0000
# Epoch 1/3, Batch 258/1000, Loss: 0.0000
# Epoch 1/3, Batch 259/1000, Loss: 0.0000
# Epoch 1/3, Batch 260/1000, Loss: 0.0001
# Epoch 1/3, Batch 261/1000, Loss: 0.0000
# Epoch 1/3, Batch 262/1000, Loss: 0.0002
# Epoch 1/3, Batch 263/1000, Loss: 0.0000
# Epoch 1/3, Batch 264/1000, Loss: 0.0001
# Epoch 1/3, Batch 265/1000, Loss: 0.0000
# Epoch 1/3, Batch 266/1000, Loss: 0.0000
# Epoch 1/3, Batch 267/1000, Loss: 0.0000
# Epoch 1/3, Batch 268/1000, Loss: 0.0000
# Epoch 1/3, Batch 269/1000, Loss: 0.0000
# Epoch 1/3, Batch 270/1000, Loss: 0.0000
# Epoch 1/3, Batch 271/1000, Loss: 0.0000
# Epoch 1/3, Batch 272/1000, Loss: 0.0000
# Epoch 1/3, Batch 273/1000, Loss: 0.0000
# Epoch 1/3, Batch 274/1000, Loss: 0.0000
# Epoch 1/3, Batch 275/1000, Loss: 0.0001
# Epoch 1/3, Batch 276/1000, Loss: 0.0001
# Epoch 1/3, Batch 277/1000, Loss: 0.0000
# Epoch 1/3, Batch 278/1000, Loss: 0.0001
# Epoch 1/3, Batch 279/1000, Loss: 0.0000
# Epoch 1/3, Batch 280/1000, Loss: 0.0000
# Epoch 1/3, Batch 281/1000, Loss: 0.0001
# Epoch 1/3, Batch 282/1000, Loss: 0.0001
# Epoch 1/3, Batch 283/1000, Loss: 0.0000
# Epoch 1/3, Batch 284/1000, Loss: 0.0000
# Epoch 1/3, Batch 285/1000, Loss: 0.0000
# Epoch 1/3, Batch 286/1000, Loss: 0.0000
# Epoch 1/3, Batch 287/1000, Loss: 0.0000
# Epoch 1/3, Batch 288/1000, Loss: 0.0000
# Epoch 1/3, Batch 289/1000, Loss: 0.0001
# Epoch 1/3, Batch 290/1000, Loss: 0.0000
# Epoch 1/3, Batch 291/1000, Loss: 0.0000
# Epoch 1/3, Batch 292/1000, Loss: 0.0001
# Epoch 1/3, Batch 293/1000, Loss: 0.0001
# Epoch 1/3, Batch 294/1000, Loss: 0.0001
# Epoch 1/3, Batch 295/1000, Loss: 0.0001
# Epoch 1/3, Batch 296/1000, Loss: 0.0000
# Epoch 1/3, Batch 297/1000, Loss: 0.0000
# Epoch 1/3, Batch 298/1000, Loss: 0.0001
# Epoch 1/3, Batch 299/1000, Loss: 0.0000
# Epoch 1/3, Batch 300/1000, Loss: 0.0001
# Epoch 1/3, Batch 301/1000, Loss: 0.0001
# Epoch 1/3, Batch 302/1000, Loss: 0.0000
# Epoch 1/3, Batch 303/1000, Loss: 0.0001
# Epoch 1/3, Batch 304/1000, Loss: 0.0001
# Epoch 1/3, Batch 305/1000, Loss: 0.0000
# Epoch 1/3, Batch 306/1000, Loss: 0.0000
# Epoch 1/3, Batch 307/1000, Loss: 0.0001
# Epoch 1/3, Batch 308/1000, Loss: 0.0001
# Epoch 1/3, Batch 309/1000, Loss: 0.0000
# Epoch 1/3, Batch 310/1000, Loss: 0.0000
# Epoch 1/3, Batch 311/1000, Loss: 0.0000
# Epoch 1/3, Batch 312/1000, Loss: 0.0000
# Epoch 1/3, Batch 313/1000, Loss: 0.0000
# Epoch 1/3, Batch 314/1000, Loss: 0.0000
# Epoch 1/3, Batch 315/1000, Loss: 0.0000
# Epoch 1/3, Batch 316/1000, Loss: 0.0000
# Epoch 1/3, Batch 317/1000, Loss: 0.0000
# Epoch 1/3, Batch 318/1000, Loss: 0.0001
# Epoch 1/3, Batch 319/1000, Loss: 0.0000
# Epoch 1/3, Batch 320/1000, Loss: 0.0000
# Epoch 1/3, Batch 321/1000, Loss: 0.0000
# Epoch 1/3, Batch 322/1000, Loss: 0.0000
# Epoch 1/3, Batch 323/1000, Loss: 0.0000
# Epoch 1/3, Batch 324/1000, Loss: 0.0000
# Epoch 1/3, Batch 325/1000, Loss: 0.0000
# Epoch 1/3, Batch 326/1000, Loss: 0.0000
# Epoch 1/3, Batch 327/1000, Loss: 0.0000
# Epoch 1/3, Batch 328/1000, Loss: 0.0000
# Epoch 1/3, Batch 329/1000, Loss: 0.0001
# Epoch 1/3, Batch 330/1000, Loss: 0.0000
# Epoch 1/3, Batch 331/1000, Loss: 0.0000
# Epoch 1/3, Batch 332/1000, Loss: 0.0000
# Epoch 1/3, Batch 333/1000, Loss: 0.0000
# Epoch 1/3, Batch 334/1000, Loss: 0.0000
# Epoch 1/3, Batch 335/1000, Loss: 0.0000
# Epoch 1/3, Batch 336/1000, Loss: 0.0000
# Epoch 1/3, Batch 337/1000, Loss: 0.0000
# Epoch 1/3, Batch 338/1000, Loss: 0.0000
# Epoch 1/3, Batch 339/1000, Loss: 0.0001
# Epoch 1/3, Batch 340/1000, Loss: 0.0000
# Epoch 1/3, Batch 341/1000, Loss: 0.0001
# Epoch 1/3, Batch 342/1000, Loss: 0.0000
# Epoch 1/3, Batch 343/1000, Loss: 0.0000
# Epoch 1/3, Batch 344/1000, Loss: 0.0000
# Epoch 1/3, Batch 345/1000, Loss: 0.0000
# Epoch 1/3, Batch 346/1000, Loss: 0.0000
# Epoch 1/3, Batch 347/1000, Loss: 0.0000
# Epoch 1/3, Batch 348/1000, Loss: 0.0000
# Epoch 1/3, Batch 349/1000, Loss: 0.0001
# Epoch 1/3, Batch 350/1000, Loss: 0.0000
# Epoch 1/3, Batch 351/1000, Loss: 0.0000
# Epoch 1/3, Batch 352/1000, Loss: 0.0000
# Epoch 1/3, Batch 353/1000, Loss: 0.0000
# Epoch 1/3, Batch 354/1000, Loss: 0.0000
# Epoch 1/3, Batch 355/1000, Loss: 0.0000
# Epoch 1/3, Batch 356/1000, Loss: 0.0000
# Epoch 1/3, Batch 357/1000, Loss: 0.0000
# Epoch 1/3, Batch 358/1000, Loss: 0.0000
# Epoch 1/3, Batch 359/1000, Loss: 0.0001
# Epoch 1/3, Batch 360/1000, Loss: 0.0001
# Epoch 1/3, Batch 361/1000, Loss: 0.0000
# Epoch 1/3, Batch 362/1000, Loss: 0.0000
# Epoch 1/3, Batch 363/1000, Loss: 0.0000
# Epoch 1/3, Batch 364/1000, Loss: 0.0000
# Epoch 1/3, Batch 365/1000, Loss: 0.0001
# Epoch 1/3, Batch 366/1000, Loss: 0.0000
# Epoch 1/3, Batch 367/1000, Loss: 0.0000
# Epoch 1/3, Batch 368/1000, Loss: 0.0000
# Epoch 1/3, Batch 369/1000, Loss: 0.0000
# Epoch 1/3, Batch 370/1000, Loss: 0.0000
# Epoch 1/3, Batch 371/1000, Loss: 0.0000
# Epoch 1/3, Batch 372/1000, Loss: 0.0000
# Epoch 1/3, Batch 373/1000, Loss: 0.0000
# Epoch 1/3, Batch 374/1000, Loss: 0.0000
# Epoch 1/3, Batch 375/1000, Loss: 0.0000
# Epoch 1/3, Batch 376/1000, Loss: 0.0000
# Epoch 1/3, Batch 377/1000, Loss: 0.0000
# Epoch 1/3, Batch 378/1000, Loss: 0.0000
# Epoch 1/3, Batch 379/1000, Loss: 0.0000
# Epoch 1/3, Batch 380/1000, Loss: 0.0001
# Epoch 1/3, Batch 381/1000, Loss: 0.0000
# Epoch 1/3, Batch 382/1000, Loss: 0.0000
# Epoch 1/3, Batch 383/1000, Loss: 0.0000
# Epoch 1/3, Batch 384/1000, Loss: 0.0000
# Epoch 1/3, Batch 385/1000, Loss: 0.0001
# Epoch 1/3, Batch 386/1000, Loss: 0.0000
# Epoch 1/3, Batch 387/1000, Loss: 0.0000
# Epoch 1/3, Batch 388/1000, Loss: 0.0001
# Epoch 1/3, Batch 389/1000, Loss: 0.0000
# Epoch 1/3, Batch 390/1000, Loss: 0.0000
# Epoch 1/3, Batch 391/1000, Loss: 0.0000
# Epoch 1/3, Batch 392/1000, Loss: 0.0000
# Epoch 1/3, Batch 393/1000, Loss: 0.0000
# Epoch 1/3, Batch 394/1000, Loss: 0.0000
# Epoch 1/3, Batch 395/1000, Loss: 0.0000
# Epoch 1/3, Batch 396/1000, Loss: 0.0000
# Epoch 1/3, Batch 397/1000, Loss: 0.0000
# Epoch 1/3, Batch 398/1000, Loss: 0.0000
# Epoch 1/3, Batch 399/1000, Loss: 0.0000
# Epoch 1/3, Batch 400/1000, Loss: 0.0000
# Epoch 1/3, Batch 401/1000, Loss: 0.0000
# Epoch 1/3, Batch 402/1000, Loss: 0.0000
# Epoch 1/3, Batch 403/1000, Loss: 0.0000
# Epoch 1/3, Batch 404/1000, Loss: 0.0001
# Epoch 1/3, Batch 405/1000, Loss: 0.0000
# Epoch 1/3, Batch 406/1000, Loss: 0.0001
# Epoch 1/3, Batch 407/1000, Loss: 0.0000
# Epoch 1/3, Batch 408/1000, Loss: 0.0001
# Epoch 1/3, Batch 409/1000, Loss: 0.0000
# Epoch 1/3, Batch 410/1000, Loss: 0.0000
# Epoch 1/3, Batch 411/1000, Loss: 0.0001
# Epoch 1/3, Batch 412/1000, Loss: 0.0000
# Epoch 1/3, Batch 413/1000, Loss: 0.0000
# Epoch 1/3, Batch 414/1000, Loss: 0.0000
# Epoch 1/3, Batch 415/1000, Loss: 0.0001
# Epoch 1/3, Batch 416/1000, Loss: 0.0000
# Epoch 1/3, Batch 417/1000, Loss: 0.0000
# Epoch 1/3, Batch 418/1000, Loss: 0.0000
# Epoch 1/3, Batch 419/1000, Loss: 0.0000
# Epoch 1/3, Batch 420/1000, Loss: 0.0000
# Epoch 1/3, Batch 421/1000, Loss: 0.0000
# Epoch 1/3, Batch 422/1000, Loss: 0.0001
# Epoch 1/3, Batch 423/1000, Loss: 0.0000
# Epoch 1/3, Batch 424/1000, Loss: 0.0000
# Epoch 1/3, Batch 425/1000, Loss: 0.0000
# Epoch 1/3, Batch 426/1000, Loss: 0.0000
# Epoch 1/3, Batch 427/1000, Loss: 0.0000
# Epoch 1/3, Batch 428/1000, Loss: 0.0000
# Epoch 1/3, Batch 429/1000, Loss: 0.0000
# Epoch 1/3, Batch 430/1000, Loss: 0.0000
# Epoch 1/3, Batch 431/1000, Loss: 0.0000
# Epoch 1/3, Batch 432/1000, Loss: 0.0000
# Epoch 1/3, Batch 433/1000, Loss: 0.0001
# Epoch 1/3, Batch 434/1000, Loss: 0.0000
# Epoch 1/3, Batch 435/1000, Loss: 0.0000
# Epoch 1/3, Batch 436/1000, Loss: 0.0000
# Epoch 1/3, Batch 437/1000, Loss: 0.0001
# Epoch 1/3, Batch 438/1000, Loss: 0.0000
# Epoch 1/3, Batch 439/1000, Loss: 0.0001
# Epoch 1/3, Batch 440/1000, Loss: 0.0000
# Epoch 1/3, Batch 441/1000, Loss: 0.0000
# Epoch 1/3, Batch 442/1000, Loss: 0.0000
# Epoch 1/3, Batch 443/1000, Loss: 0.0000
# Epoch 1/3, Batch 444/1000, Loss: 0.0000
# Epoch 1/3, Batch 445/1000, Loss: 0.0000
# Epoch 1/3, Batch 446/1000, Loss: 0.0000
# Epoch 1/3, Batch 447/1000, Loss: 0.0000
# Epoch 1/3, Batch 448/1000, Loss: 0.0000
# Epoch 1/3, Batch 449/1000, Loss: 0.0001
# Epoch 1/3, Batch 450/1000, Loss: 0.0000
# Epoch 1/3, Batch 451/1000, Loss: 0.0000
# Epoch 1/3, Batch 452/1000, Loss: 0.0000
# Epoch 1/3, Batch 453/1000, Loss: 0.0000
# Epoch 1/3, Batch 454/1000, Loss: 0.0000
# Epoch 1/3, Batch 455/1000, Loss: 0.0000
# Epoch 1/3, Batch 456/1000, Loss: 0.0000
# Epoch 1/3, Batch 457/1000, Loss: 0.0000
# Epoch 1/3, Batch 458/1000, Loss: 0.0000
# Epoch 1/3, Batch 459/1000, Loss: 0.0000
# Epoch 1/3, Batch 460/1000, Loss: 0.0000
# Epoch 1/3, Batch 461/1000, Loss: 0.0000
# Epoch 1/3, Batch 462/1000, Loss: 0.0000
# Epoch 1/3, Batch 463/1000, Loss: 0.0000
# Epoch 1/3, Batch 464/1000, Loss: 0.0001
# Epoch 1/3, Batch 465/1000, Loss: 0.0000
# Epoch 1/3, Batch 466/1000, Loss: 0.0000
# Epoch 1/3, Batch 467/1000, Loss: 0.0000
# Epoch 1/3, Batch 468/1000, Loss: 0.0001
# Epoch 1/3, Batch 469/1000, Loss: 0.0000
# Epoch 1/3, Batch 470/1000, Loss: 0.0000
# Epoch 1/3, Batch 471/1000, Loss: 0.0000
# Epoch 1/3, Batch 472/1000, Loss: 0.0000
# Epoch 1/3, Batch 473/1000, Loss: 0.0000
# Epoch 1/3, Batch 474/1000, Loss: 0.0000
# Epoch 1/3, Batch 475/1000, Loss: 0.0000
# Epoch 1/3, Batch 476/1000, Loss: 0.0000
# Epoch 1/3, Batch 477/1000, Loss: 0.0000
# Epoch 1/3, Batch 478/1000, Loss: 0.0001
# Epoch 1/3, Batch 479/1000, Loss: 0.0000
# Epoch 1/3, Batch 480/1000, Loss: 0.0000
# Epoch 1/3, Batch 481/1000, Loss: 0.0000
# Epoch 1/3, Batch 482/1000, Loss: 0.0001
# Epoch 1/3, Batch 483/1000, Loss: 0.0000
# Epoch 1/3, Batch 484/1000, Loss: 0.0000
# Epoch 1/3, Batch 485/1000, Loss: 0.0000
# Epoch 1/3, Batch 486/1000, Loss: 0.0000
# Epoch 1/3, Batch 487/1000, Loss: 0.0000
# Epoch 1/3, Batch 488/1000, Loss: 0.0000
# Epoch 1/3, Batch 489/1000, Loss: 0.0000
# Epoch 1/3, Batch 490/1000, Loss: 0.0000
# Epoch 1/3, Batch 491/1000, Loss: 0.0000
# Epoch 1/3, Batch 492/1000, Loss: 0.0000
# Epoch 1/3, Batch 493/1000, Loss: 0.0000
# Epoch 1/3, Batch 494/1000, Loss: 0.0000
# Epoch 1/3, Batch 495/1000, Loss: 0.0000
# Epoch 1/3, Batch 496/1000, Loss: 0.0000
# Epoch 1/3, Batch 497/1000, Loss: 0.0000
# Epoch 1/3, Batch 498/1000, Loss: 0.0000
# Epoch 1/3, Batch 499/1000, Loss: 0.0000
# Epoch 1/3, Batch 500/1000, Loss: 0.0000
# Epoch 1/3, Batch 501/1000, Loss: 0.0000
# Epoch 1/3, Batch 502/1000, Loss: 0.0000
# Epoch 1/3, Batch 503/1000, Loss: 0.0000
# Epoch 1/3, Batch 504/1000, Loss: 0.0000
# Epoch 1/3, Batch 505/1000, Loss: 0.0000
# Epoch 1/3, Batch 506/1000, Loss: 0.0000
# Epoch 1/3, Batch 507/1000, Loss: 0.0000
# Epoch 1/3, Batch 508/1000, Loss: 0.0000
# Epoch 1/3, Batch 509/1000, Loss: 0.0000
# Epoch 1/3, Batch 510/1000, Loss: 0.0000
# Epoch 1/3, Batch 511/1000, Loss: 0.0000
# Epoch 1/3, Batch 512/1000, Loss: 0.0000
# Epoch 1/3, Batch 513/1000, Loss: 0.0000
# Epoch 1/3, Batch 514/1000, Loss: 0.0000
# Epoch 1/3, Batch 515/1000, Loss: 0.0000
# Epoch 1/3, Batch 516/1000, Loss: 0.0000
# Epoch 1/3, Batch 517/1000, Loss: 0.0000
# Epoch 1/3, Batch 518/1000, Loss: 0.0000
# Epoch 1/3, Batch 519/1000, Loss: 0.0000
# Epoch 1/3, Batch 520/1000, Loss: 0.0000
# Epoch 1/3, Batch 521/1000, Loss: 0.0000
# Epoch 1/3, Batch 522/1000, Loss: 0.0000
# Epoch 1/3, Batch 523/1000, Loss: 0.0000
# Epoch 1/3, Batch 524/1000, Loss: 0.0000
# Epoch 1/3, Batch 525/1000, Loss: 0.0000
# Epoch 1/3, Batch 526/1000, Loss: 0.0000
# Epoch 1/3, Batch 527/1000, Loss: 0.0000
# Epoch 1/3, Batch 528/1000, Loss: 0.0000
# Epoch 1/3, Batch 529/1000, Loss: 0.0000
# Epoch 1/3, Batch 530/1000, Loss: 0.0000
# Epoch 1/3, Batch 531/1000, Loss: 0.0000
# Epoch 1/3, Batch 532/1000, Loss: 0.0000
# Epoch 1/3, Batch 533/1000, Loss: 0.0001
# Epoch 1/3, Batch 534/1000, Loss: 0.0000
# Epoch 1/3, Batch 535/1000, Loss: 0.0000
# Epoch 1/3, Batch 536/1000, Loss: 0.0000
# Epoch 1/3, Batch 537/1000, Loss: 0.0000
# Epoch 1/3, Batch 538/1000, Loss: 0.0000
# Epoch 1/3, Batch 539/1000, Loss: 0.0000
# Epoch 1/3, Batch 540/1000, Loss: 0.0000
# Epoch 1/3, Batch 541/1000, Loss: 0.0000
# Epoch 1/3, Batch 542/1000, Loss: 0.0000
# Epoch 1/3, Batch 543/1000, Loss: 0.0000
# Epoch 1/3, Batch 544/1000, Loss: 0.0000
# Epoch 1/3, Batch 545/1000, Loss: 0.0000
# Epoch 1/3, Batch 546/1000, Loss: 0.0000
# Epoch 1/3, Batch 547/1000, Loss: 0.0000
# Epoch 1/3, Batch 548/1000, Loss: 0.0000
# Epoch 1/3, Batch 549/1000, Loss: 0.0000
# Epoch 1/3, Batch 550/1000, Loss: 0.0000
# Epoch 1/3, Batch 551/1000, Loss: 0.0000
# Epoch 1/3, Batch 552/1000, Loss: 0.0000
# Epoch 1/3, Batch 553/1000, Loss: 0.0000
# Epoch 1/3, Batch 554/1000, Loss: 0.0000
# Epoch 1/3, Batch 555/1000, Loss: 0.0000
# Epoch 1/3, Batch 556/1000, Loss: 0.0000
# Epoch 1/3, Batch 557/1000, Loss: 0.0000
# Epoch 1/3, Batch 558/1000, Loss: 0.0000
# Epoch 1/3, Batch 559/1000, Loss: 0.0000
# Epoch 1/3, Batch 560/1000, Loss: 0.0000
# Epoch 1/3, Batch 561/1000, Loss: 0.0000
# Epoch 1/3, Batch 562/1000, Loss: 0.0001
# Epoch 1/3, Batch 563/1000, Loss: 0.0000
# Epoch 1/3, Batch 564/1000, Loss: 0.0001
# Epoch 1/3, Batch 565/1000, Loss: 0.0000
# Epoch 1/3, Batch 566/1000, Loss: 0.0000
# Epoch 1/3, Batch 567/1000, Loss: 0.0000
# Epoch 1/3, Batch 568/1000, Loss: 0.0000
# Epoch 1/3, Batch 569/1000, Loss: 0.0000
# Epoch 1/3, Batch 570/1000, Loss: 0.0000
# Epoch 1/3, Batch 571/1000, Loss: 0.0000
# Epoch 1/3, Batch 572/1000, Loss: 0.0000
# Epoch 1/3, Batch 573/1000, Loss: 0.0001
# Epoch 1/3, Batch 574/1000, Loss: 0.0000
# Epoch 1/3, Batch 575/1000, Loss: 0.0000
# Epoch 1/3, Batch 576/1000, Loss: 0.0000
# Epoch 1/3, Batch 577/1000, Loss: 0.0000
# Epoch 1/3, Batch 578/1000, Loss: 0.0000
# Epoch 1/3, Batch 579/1000, Loss: 0.0000
# Epoch 1/3, Batch 580/1000, Loss: 0.0000
# Epoch 1/3, Batch 581/1000, Loss: 0.0000
# Epoch 1/3, Batch 582/1000, Loss: 0.0000
# Epoch 1/3, Batch 583/1000, Loss: 0.0000
# Epoch 1/3, Batch 584/1000, Loss: 0.0000
# Epoch 1/3, Batch 585/1000, Loss: 0.0000
# Epoch 1/3, Batch 586/1000, Loss: 0.0000
# Epoch 1/3, Batch 587/1000, Loss: 0.0000
# Epoch 1/3, Batch 588/1000, Loss: 0.0000
# Epoch 1/3, Batch 589/1000, Loss: 0.0000
# Epoch 1/3, Batch 590/1000, Loss: 0.0000
# Epoch 1/3, Batch 591/1000, Loss: 0.0000
# Epoch 1/3, Batch 592/1000, Loss: 0.0000
# Epoch 1/3, Batch 593/1000, Loss: 0.0000
# Epoch 1/3, Batch 594/1000, Loss: 0.0000
# Epoch 1/3, Batch 595/1000, Loss: 0.0000
# Epoch 1/3, Batch 596/1000, Loss: 0.0000
# Epoch 1/3, Batch 597/1000, Loss: 0.0000
# Epoch 1/3, Batch 598/1000, Loss: 0.0000
# Epoch 1/3, Batch 599/1000, Loss: 0.0000
# Epoch 1/3, Batch 600/1000, Loss: 0.0000
# Epoch 1/3, Batch 601/1000, Loss: 0.0000
# Epoch 1/3, Batch 602/1000, Loss: 0.0000
# Epoch 1/3, Batch 603/1000, Loss: 0.0000
# Epoch 1/3, Batch 604/1000, Loss: 0.0001
# Epoch 1/3, Batch 605/1000, Loss: 0.0000
# Epoch 1/3, Batch 606/1000, Loss: 0.0000
# Epoch 1/3, Batch 607/1000, Loss: 0.0000
# Epoch 1/3, Batch 608/1000, Loss: 0.0000
# Epoch 1/3, Batch 609/1000, Loss: 0.0000
# Epoch 1/3, Batch 610/1000, Loss: 0.0000
# Epoch 1/3, Batch 611/1000, Loss: 0.0000
# Epoch 1/3, Batch 612/1000, Loss: 0.0000
# Epoch 1/3, Batch 613/1000, Loss: 0.0000
# Epoch 1/3, Batch 614/1000, Loss: 0.0000
# Epoch 1/3, Batch 615/1000, Loss: 0.0000
# Epoch 1/3, Batch 616/1000, Loss: 0.0001
# Epoch 1/3, Batch 617/1000, Loss: 0.0000
# Epoch 1/3, Batch 618/1000, Loss: 0.0000
# Epoch 1/3, Batch 619/1000, Loss: 0.0000
# Epoch 1/3, Batch 620/1000, Loss: 0.0000
# Epoch 1/3, Batch 621/1000, Loss: 0.0000
# Epoch 1/3, Batch 622/1000, Loss: 0.0000
# Epoch 1/3, Batch 623/1000, Loss: 0.0000
# Epoch 1/3, Batch 624/1000, Loss: 0.0000
# Epoch 1/3, Batch 625/1000, Loss: 0.0000
# Epoch 1/3, Batch 626/1000, Loss: 0.0000
# Epoch 1/3, Batch 627/1000, Loss: 0.0000
# Epoch 1/3, Batch 628/1000, Loss: 0.0000
# Epoch 1/3, Batch 629/1000, Loss: 0.0000
# Epoch 1/3, Batch 630/1000, Loss: 0.0000
# Epoch 1/3, Batch 631/1000, Loss: 0.0001
# Epoch 1/3, Batch 632/1000, Loss: 0.0000
# Epoch 1/3, Batch 633/1000, Loss: 0.0000
# Epoch 1/3, Batch 634/1000, Loss: 0.0000
# Epoch 1/3, Batch 635/1000, Loss: 0.0000
# Epoch 1/3, Batch 636/1000, Loss: 0.0000
# Epoch 1/3, Batch 637/1000, Loss: 0.0000
# Epoch 1/3, Batch 638/1000, Loss: 0.0000
# Epoch 1/3, Batch 639/1000, Loss: 0.0000
# Epoch 1/3, Batch 640/1000, Loss: 0.0000
# Epoch 1/3, Batch 641/1000, Loss: 0.0000
# Epoch 1/3, Batch 642/1000, Loss: 0.0000
# Epoch 1/3, Batch 643/1000, Loss: 0.0000
# Epoch 1/3, Batch 644/1000, Loss: 0.0000
# Epoch 1/3, Batch 645/1000, Loss: 0.0000
# Epoch 1/3, Batch 646/1000, Loss: 0.0000
# Epoch 1/3, Batch 647/1000, Loss: 0.0000
# Epoch 1/3, Batch 648/1000, Loss: 0.0000
# Epoch 1/3, Batch 649/1000, Loss: 0.0000
# Epoch 1/3, Batch 650/1000, Loss: 0.0000
# Epoch 1/3, Batch 651/1000, Loss: 0.0000
# Epoch 1/3, Batch 652/1000, Loss: 0.0000
# Epoch 1/3, Batch 653/1000, Loss: 0.0000
# Epoch 1/3, Batch 654/1000, Loss: 0.0000
# Epoch 1/3, Batch 655/1000, Loss: 0.0000
# Epoch 1/3, Batch 656/1000, Loss: 0.0000
# Epoch 1/3, Batch 657/1000, Loss: 0.0000
# Epoch 1/3, Batch 658/1000, Loss: 0.0000
# Epoch 1/3, Batch 659/1000, Loss: 0.0000
# Epoch 1/3, Batch 660/1000, Loss: 0.0000
# Epoch 1/3, Batch 661/1000, Loss: 0.0000
# Epoch 1/3, Batch 662/1000, Loss: 0.0000
# Epoch 1/3, Batch 663/1000, Loss: 0.0000
# Epoch 1/3, Batch 664/1000, Loss: 0.0000
# Epoch 1/3, Batch 665/1000, Loss: 0.0000
# Epoch 1/3, Batch 666/1000, Loss: 0.0000
# Epoch 1/3, Batch 667/1000, Loss: 0.0000
# Epoch 1/3, Batch 668/1000, Loss: 0.0000
# Epoch 1/3, Batch 669/1000, Loss: 0.0000
# Epoch 1/3, Batch 670/1000, Loss: 0.0000
# Epoch 1/3, Batch 671/1000, Loss: 0.0001
# Epoch 1/3, Batch 672/1000, Loss: 0.0000
# Epoch 1/3, Batch 673/1000, Loss: 0.0000
# Epoch 1/3, Batch 674/1000, Loss: 0.0000
# Epoch 1/3, Batch 675/1000, Loss: 0.0000
# Epoch 1/3, Batch 676/1000, Loss: 0.0000
# Epoch 1/3, Batch 677/1000, Loss: 0.0000
# Epoch 1/3, Batch 678/1000, Loss: 0.0000
# Epoch 1/3, Batch 679/1000, Loss: 0.0000
# Epoch 1/3, Batch 680/1000, Loss: 0.0000
# Epoch 1/3, Batch 681/1000, Loss: 0.0000
# Epoch 1/3, Batch 682/1000, Loss: 0.0000
# Epoch 1/3, Batch 683/1000, Loss: 0.0000
# Epoch 1/3, Batch 684/1000, Loss: 0.0000
# Epoch 1/3, Batch 685/1000, Loss: 0.0000
# Epoch 1/3, Batch 686/1000, Loss: 0.0000
# Epoch 1/3, Batch 687/1000, Loss: 0.0000
# Epoch 1/3, Batch 688/1000, Loss: 0.0000
# Epoch 1/3, Batch 689/1000, Loss: 0.0000
# Epoch 1/3, Batch 690/1000, Loss: 0.0000
# Epoch 1/3, Batch 691/1000, Loss: 0.0000
# Epoch 1/3, Batch 692/1000, Loss: 0.0000
# Epoch 1/3, Batch 693/1000, Loss: 0.0000
# Epoch 1/3, Batch 694/1000, Loss: 0.0000
# Epoch 1/3, Batch 695/1000, Loss: 0.0000
# Epoch 1/3, Batch 696/1000, Loss: 0.0000
# Epoch 1/3, Batch 697/1000, Loss: 0.0000
# Epoch 1/3, Batch 698/1000, Loss: 0.0000
# Epoch 1/3, Batch 699/1000, Loss: 0.0000
# Epoch 1/3, Batch 700/1000, Loss: 0.0000
# Epoch 1/3, Batch 701/1000, Loss: 0.0000
# Epoch 1/3, Batch 702/1000, Loss: 0.0000
# Epoch 1/3, Batch 703/1000, Loss: 0.0000
# Epoch 1/3, Batch 704/1000, Loss: 0.0000
# Epoch 1/3, Batch 705/1000, Loss: 0.0000
# Epoch 1/3, Batch 706/1000, Loss: 0.0000
# Epoch 1/3, Batch 707/1000, Loss: 0.0000
# Epoch 1/3, Batch 708/1000, Loss: 0.0000
# Epoch 1/3, Batch 709/1000, Loss: 0.0000
# Epoch 1/3, Batch 710/1000, Loss: 0.0000
# Epoch 1/3, Batch 711/1000, Loss: 0.0000
# Epoch 1/3, Batch 712/1000, Loss: 0.0000
# Epoch 1/3, Batch 713/1000, Loss: 0.0000
# Epoch 1/3, Batch 714/1000, Loss: 0.0000
# Epoch 1/3, Batch 715/1000, Loss: 0.0000
# Epoch 1/3, Batch 716/1000, Loss: 0.0000
# Epoch 1/3, Batch 717/1000, Loss: 0.0000
# Epoch 1/3, Batch 718/1000, Loss: 0.0000
# Epoch 1/3, Batch 719/1000, Loss: 0.0000
# Epoch 1/3, Batch 720/1000, Loss: 0.0000
# Epoch 1/3, Batch 721/1000, Loss: 0.0000
# Epoch 1/3, Batch 722/1000, Loss: 0.0000
# Epoch 1/3, Batch 723/1000, Loss: 0.0000
# Epoch 1/3, Batch 724/1000, Loss: 0.0000
# Epoch 1/3, Batch 725/1000, Loss: 0.0000
# Epoch 1/3, Batch 726/1000, Loss: 0.0000
# Epoch 1/3, Batch 727/1000, Loss: 0.0000
# Epoch 1/3, Batch 728/1000, Loss: 0.0000
# Epoch 1/3, Batch 729/1000, Loss: 0.0000
# Epoch 1/3, Batch 730/1000, Loss: 0.0000
# Epoch 1/3, Batch 731/1000, Loss: 0.0000
# Epoch 1/3, Batch 732/1000, Loss: 0.0000
# Epoch 1/3, Batch 733/1000, Loss: 0.0000
# Epoch 1/3, Batch 734/1000, Loss: 0.0000
# Epoch 1/3, Batch 735/1000, Loss: 0.0000
# Epoch 1/3, Batch 736/1000, Loss: 0.0000
# Epoch 1/3, Batch 737/1000, Loss: 0.0001
# Epoch 1/3, Batch 738/1000, Loss: 0.0000
# Epoch 1/3, Batch 739/1000, Loss: 0.0000
# Epoch 1/3, Batch 740/1000, Loss: 0.0000
# Epoch 1/3, Batch 741/1000, Loss: 0.0000
# Epoch 1/3, Batch 742/1000, Loss: 0.0000
# Epoch 1/3, Batch 743/1000, Loss: 0.0000
# Epoch 1/3, Batch 744/1000, Loss: 0.0000
# Epoch 1/3, Batch 745/1000, Loss: 0.0000
# Epoch 1/3, Batch 746/1000, Loss: 0.0000
# Epoch 1/3, Batch 747/1000, Loss: 0.0000
# Epoch 1/3, Batch 748/1000, Loss: 0.0000
# Epoch 1/3, Batch 749/1000, Loss: 0.0000
# Epoch 1/3, Batch 750/1000, Loss: 0.0000
# Epoch 1/3, Batch 751/1000, Loss: 0.0000
# Epoch 1/3, Batch 752/1000, Loss: 0.0000
# Epoch 1/3, Batch 753/1000, Loss: 0.0000
# Epoch 1/3, Batch 754/1000, Loss: 0.0000
# Epoch 1/3, Batch 755/1000, Loss: 0.0000
# Epoch 1/3, Batch 756/1000, Loss: 0.0000
# Epoch 1/3, Batch 757/1000, Loss: 0.0000
# Epoch 1/3, Batch 758/1000, Loss: 0.0001
# Epoch 1/3, Batch 759/1000, Loss: 0.0000
# Epoch 1/3, Batch 760/1000, Loss: 0.0000
# Epoch 1/3, Batch 761/1000, Loss: 0.0000
# Epoch 1/3, Batch 762/1000, Loss: 0.0000
# Epoch 1/3, Batch 763/1000, Loss: 0.0000
# Epoch 1/3, Batch 764/1000, Loss: 0.0000
# Epoch 1/3, Batch 765/1000, Loss: 0.0000
# Epoch 1/3, Batch 766/1000, Loss: 0.0000
# Epoch 1/3, Batch 767/1000, Loss: 0.0000
# Epoch 1/3, Batch 768/1000, Loss: 0.0000
# Epoch 1/3, Batch 769/1000, Loss: 0.0000
# Epoch 1/3, Batch 770/1000, Loss: 0.0000
# Epoch 1/3, Batch 771/1000, Loss: 0.0000
# Epoch 1/3, Batch 772/1000, Loss: 0.0000
# Epoch 1/3, Batch 773/1000, Loss: 0.0000
# Epoch 1/3, Batch 774/1000, Loss: 0.0000
# Epoch 1/3, Batch 775/1000, Loss: 0.0000
# Epoch 1/3, Batch 776/1000, Loss: 0.0000
# Epoch 1/3, Batch 777/1000, Loss: 0.0000
# Epoch 1/3, Batch 778/1000, Loss: 0.0000
# Epoch 1/3, Batch 779/1000, Loss: 0.0000
# Epoch 1/3, Batch 780/1000, Loss: 0.0000
# Epoch 1/3, Batch 781/1000, Loss: 0.0000
# Epoch 1/3, Batch 782/1000, Loss: 0.0000
# Epoch 1/3, Batch 783/1000, Loss: 0.0000
# Epoch 1/3, Batch 784/1000, Loss: 0.0000
# Epoch 1/3, Batch 785/1000, Loss: 0.0000
# Epoch 1/3, Batch 786/1000, Loss: 0.0000
# Epoch 1/3, Batch 787/1000, Loss: 0.0000
# Epoch 1/3, Batch 788/1000, Loss: 0.0000
# Epoch 1/3, Batch 789/1000, Loss: 0.0000
# Epoch 1/3, Batch 790/1000, Loss: 0.0000
# Epoch 1/3, Batch 791/1000, Loss: 0.0000
# Epoch 1/3, Batch 792/1000, Loss: 0.0000
# Epoch 1/3, Batch 793/1000, Loss: 0.0000
# Epoch 1/3, Batch 794/1000, Loss: 0.0000
# Epoch 1/3, Batch 795/1000, Loss: 0.0001
# Epoch 1/3, Batch 796/1000, Loss: 0.0000
# Epoch 1/3, Batch 797/1000, Loss: 0.0000
# Epoch 1/3, Batch 798/1000, Loss: 0.0000
# Epoch 1/3, Batch 799/1000, Loss: 0.0000
# Epoch 1/3, Batch 800/1000, Loss: 0.0000
# Epoch 1/3, Batch 801/1000, Loss: 0.0000
# Epoch 1/3, Batch 802/1000, Loss: 0.0000
# Epoch 1/3, Batch 803/1000, Loss: 0.0000
# Epoch 1/3, Batch 804/1000, Loss: 0.0000
# Epoch 1/3, Batch 805/1000, Loss: 0.0000
# Epoch 1/3, Batch 806/1000, Loss: 0.0000
# Epoch 1/3, Batch 807/1000, Loss: 0.0000
# Epoch 1/3, Batch 808/1000, Loss: 0.0000
# Epoch 1/3, Batch 809/1000, Loss: 0.0000
# Epoch 1/3, Batch 810/1000, Loss: 0.0000
# Epoch 1/3, Batch 811/1000, Loss: 0.0000
# Epoch 1/3, Batch 812/1000, Loss: 0.0000
# Epoch 1/3, Batch 813/1000, Loss: 0.0000
# Epoch 1/3, Batch 814/1000, Loss: 0.0000
# Epoch 1/3, Batch 815/1000, Loss: 0.0000
# Epoch 1/3, Batch 816/1000, Loss: 0.0000
# Epoch 1/3, Batch 817/1000, Loss: 0.0000
# Epoch 1/3, Batch 818/1000, Loss: 0.0000
# Epoch 1/3, Batch 819/1000, Loss: 0.0000
# Epoch 1/3, Batch 820/1000, Loss: 0.0000
# Epoch 1/3, Batch 821/1000, Loss: 0.0000
# Epoch 1/3, Batch 822/1000, Loss: 0.0000
# Epoch 1/3, Batch 823/1000, Loss: 0.0000
# Epoch 1/3, Batch 824/1000, Loss: 0.0000
# Epoch 1/3, Batch 825/1000, Loss: 0.0000
# Epoch 1/3, Batch 826/1000, Loss: 0.0000
# Epoch 1/3, Batch 827/1000, Loss: 0.0000
# Epoch 1/3, Batch 828/1000, Loss: 0.0000
# Epoch 1/3, Batch 829/1000, Loss: 0.0000
# Epoch 1/3, Batch 830/1000, Loss: 0.0000
# Epoch 1/3, Batch 831/1000, Loss: 0.0000
# Epoch 1/3, Batch 832/1000, Loss: 0.0000
# Epoch 1/3, Batch 833/1000, Loss: 0.0000
# Epoch 1/3, Batch 834/1000, Loss: 0.0000
# Epoch 1/3, Batch 835/1000, Loss: 0.0000
# Epoch 1/3, Batch 836/1000, Loss: 0.0000
# Epoch 1/3, Batch 837/1000, Loss: 0.0000
# Epoch 1/3, Batch 838/1000, Loss: 0.0000
# Epoch 1/3, Batch 839/1000, Loss: 0.0000
# Epoch 1/3, Batch 840/1000, Loss: 0.0000
# Epoch 1/3, Batch 841/1000, Loss: 0.0000
# Epoch 1/3, Batch 842/1000, Loss: 0.0000
# Epoch 1/3, Batch 843/1000, Loss: 0.0000
# Epoch 1/3, Batch 844/1000, Loss: 0.0000
# Epoch 1/3, Batch 845/1000, Loss: 0.0000
# Epoch 1/3, Batch 846/1000, Loss: 0.0000
# Epoch 1/3, Batch 847/1000, Loss: 0.0000
# Epoch 1/3, Batch 848/1000, Loss: 0.0000
# Epoch 1/3, Batch 849/1000, Loss: 0.0000
# Epoch 1/3, Batch 850/1000, Loss: 0.0000
# Epoch 1/3, Batch 851/1000, Loss: 0.0000
# Epoch 1/3, Batch 852/1000, Loss: 0.0000
# Epoch 1/3, Batch 853/1000, Loss: 0.0000
# Epoch 1/3, Batch 854/1000, Loss: 0.0000
# Epoch 1/3, Batch 855/1000, Loss: 0.0000
# Epoch 1/3, Batch 856/1000, Loss: 0.0000
# Epoch 1/3, Batch 857/1000, Loss: 0.0000
# Epoch 1/3, Batch 858/1000, Loss: 0.0000
# Epoch 1/3, Batch 859/1000, Loss: 0.0000
# Epoch 1/3, Batch 860/1000, Loss: 0.0000
# Epoch 1/3, Batch 861/1000, Loss: 0.0000
# Epoch 1/3, Batch 862/1000, Loss: 0.0000
# Epoch 1/3, Batch 863/1000, Loss: 0.0000
# Epoch 1/3, Batch 864/1000, Loss: 0.0000
# Epoch 1/3, Batch 865/1000, Loss: 0.0000
# Epoch 1/3, Batch 866/1000, Loss: 0.0000
# Epoch 1/3, Batch 867/1000, Loss: 0.0000
# Epoch 1/3, Batch 868/1000, Loss: 0.0000
# Epoch 1/3, Batch 869/1000, Loss: 0.0000
# Epoch 1/3, Batch 870/1000, Loss: 0.0000
# Epoch 1/3, Batch 871/1000, Loss: 0.0000
# Epoch 1/3, Batch 872/1000, Loss: 0.0000
# Epoch 1/3, Batch 873/1000, Loss: 0.0000
# Epoch 1/3, Batch 874/1000, Loss: 0.0000
# Epoch 1/3, Batch 875/1000, Loss: 0.0000
# Epoch 1/3, Batch 876/1000, Loss: 0.0000
# Epoch 1/3, Batch 877/1000, Loss: 0.0000
# Epoch 1/3, Batch 878/1000, Loss: 0.0000
# Epoch 1/3, Batch 879/1000, Loss: 0.0000
# Epoch 1/3, Batch 880/1000, Loss: 0.0000
# Epoch 1/3, Batch 881/1000, Loss: 0.0000
# Epoch 1/3, Batch 882/1000, Loss: 0.0000
# Epoch 1/3, Batch 883/1000, Loss: 0.0000
# Epoch 1/3, Batch 884/1000, Loss: 0.0000
# Epoch 1/3, Batch 885/1000, Loss: 0.0000
# Epoch 1/3, Batch 886/1000, Loss: 0.0000
# Epoch 1/3, Batch 887/1000, Loss: 0.0000
# Epoch 1/3, Batch 888/1000, Loss: 0.0000
# Epoch 1/3, Batch 889/1000, Loss: 0.0000
# Epoch 1/3, Batch 890/1000, Loss: 0.0000
# Epoch 1/3, Batch 891/1000, Loss: 0.0000
# Epoch 1/3, Batch 892/1000, Loss: 0.0000
# Epoch 1/3, Batch 893/1000, Loss: 0.0000
# Epoch 1/3, Batch 894/1000, Loss: 0.0000
# Epoch 1/3, Batch 895/1000, Loss: 0.0000
# Epoch 1/3, Batch 896/1000, Loss: 0.0000
# Epoch 1/3, Batch 897/1000, Loss: 0.0000
# Epoch 1/3, Batch 898/1000, Loss: 0.0001
# Epoch 1/3, Batch 899/1000, Loss: 0.0000
# Epoch 1/3, Batch 900/1000, Loss: 0.0000
# Epoch 1/3, Batch 901/1000, Loss: 0.0000
# Epoch 1/3, Batch 902/1000, Loss: 0.0000
# Epoch 1/3, Batch 903/1000, Loss: 0.0000
# Epoch 1/3, Batch 904/1000, Loss: 0.0000
# Epoch 1/3, Batch 905/1000, Loss: 0.0000
# Epoch 1/3, Batch 906/1000, Loss: 0.0000
# Epoch 1/3, Batch 907/1000, Loss: 0.0000
# Epoch 1/3, Batch 908/1000, Loss: 0.0000
# Epoch 1/3, Batch 909/1000, Loss: 0.0000
# Epoch 1/3, Batch 910/1000, Loss: 0.0000
# Epoch 1/3, Batch 911/1000, Loss: 0.0000
# Epoch 1/3, Batch 912/1000, Loss: 0.0000
# Epoch 1/3, Batch 913/1000, Loss: 0.0000
# Epoch 1/3, Batch 914/1000, Loss: 0.0000
# Epoch 1/3, Batch 915/1000, Loss: 0.0000
# Epoch 1/3, Batch 916/1000, Loss: 0.0001
# Epoch 1/3, Batch 917/1000, Loss: 0.0000
# Epoch 1/3, Batch 918/1000, Loss: 0.0000
# Epoch 1/3, Batch 919/1000, Loss: 0.0000
# Epoch 1/3, Batch 920/1000, Loss: 0.0000
# Epoch 1/3, Batch 921/1000, Loss: 0.0000
# Epoch 1/3, Batch 922/1000, Loss: 0.0000
# Epoch 1/3, Batch 923/1000, Loss: 0.0000
# Epoch 1/3, Batch 924/1000, Loss: 0.0000
# Epoch 1/3, Batch 925/1000, Loss: 0.0000
# Epoch 1/3, Batch 926/1000, Loss: 0.0000
# Epoch 1/3, Batch 927/1000, Loss: 0.0000
# Epoch 1/3, Batch 928/1000, Loss: 0.0000
# Epoch 1/3, Batch 929/1000, Loss: 0.0000
# Epoch 1/3, Batch 930/1000, Loss: 0.0000
# Epoch 1/3, Batch 931/1000, Loss: 0.0000
# Epoch 1/3, Batch 932/1000, Loss: 0.0000
# Epoch 1/3, Batch 933/1000, Loss: 0.0000
# Epoch 1/3, Batch 934/1000, Loss: 0.0000
# Epoch 1/3, Batch 935/1000, Loss: 0.0000
# Epoch 1/3, Batch 936/1000, Loss: 0.0000
# Epoch 1/3, Batch 937/1000, Loss: 0.0000
# Epoch 1/3, Batch 938/1000, Loss: 0.0000
# Epoch 1/3, Batch 939/1000, Loss: 0.0000
# Epoch 1/3, Batch 940/1000, Loss: 0.0000
# Epoch 1/3, Batch 941/1000, Loss: 0.0000
# Epoch 1/3, Batch 942/1000, Loss: 0.0000
# Epoch 1/3, Batch 943/1000, Loss: 0.0000
# Epoch 1/3, Batch 944/1000, Loss: 0.0000
# Epoch 1/3, Batch 945/1000, Loss: 0.0000
# Epoch 1/3, Batch 946/1000, Loss: 0.0000
# Epoch 1/3, Batch 947/1000, Loss: 0.0000
# Epoch 1/3, Batch 948/1000, Loss: 0.0000
# Epoch 1/3, Batch 949/1000, Loss: 0.0000
# Epoch 1/3, Batch 950/1000, Loss: 0.0000
# Epoch 1/3, Batch 951/1000, Loss: 0.0000
# Epoch 1/3, Batch 952/1000, Loss: 0.0000
# Epoch 1/3, Batch 953/1000, Loss: 0.0000
# Epoch 1/3, Batch 954/1000, Loss: 0.0000
# Epoch 1/3, Batch 955/1000, Loss: 0.0000
# Epoch 1/3, Batch 956/1000, Loss: 0.0000
# Epoch 1/3, Batch 957/1000, Loss: 0.0000
# Epoch 1/3, Batch 958/1000, Loss: 0.0000
# Epoch 1/3, Batch 959/1000, Loss: 0.0000
# Epoch 1/3, Batch 960/1000, Loss: 0.0000
# Epoch 1/3, Batch 961/1000, Loss: 0.0000
# Epoch 1/3, Batch 962/1000, Loss: 0.0000
# Epoch 1/3, Batch 963/1000, Loss: 0.0000
# Epoch 1/3, Batch 964/1000, Loss: 0.0000
# Epoch 1/3, Batch 965/1000, Loss: 0.0000
# Epoch 1/3, Batch 966/1000, Loss: 0.0000
# Epoch 1/3, Batch 967/1000, Loss: 0.0000
# Epoch 1/3, Batch 968/1000, Loss: 0.0000
# Epoch 1/3, Batch 969/1000, Loss: 0.0000
# Epoch 1/3, Batch 970/1000, Loss: 0.0000
# Epoch 1/3, Batch 971/1000, Loss: 0.0000
# Epoch 1/3, Batch 972/1000, Loss: 0.0000
# Epoch 1/3, Batch 973/1000, Loss: 0.0000
# Epoch 1/3, Batch 974/1000, Loss: 0.0000
# Epoch 1/3, Batch 975/1000, Loss: 0.0000
# Epoch 1/3, Batch 976/1000, Loss: 0.0000
# Epoch 1/3, Batch 977/1000, Loss: 0.0000
# Epoch 1/3, Batch 978/1000, Loss: 0.0000
# Epoch 1/3, Batch 979/1000, Loss: 0.0000
# Epoch 1/3, Batch 980/1000, Loss: 0.0000
# Epoch 1/3, Batch 981/1000, Loss: 0.0000
# Epoch 1/3, Batch 982/1000, Loss: 0.0000
# Epoch 1/3, Batch 983/1000, Loss: 0.0000
# Epoch 1/3, Batch 984/1000, Loss: 0.0000
# Epoch 1/3, Batch 985/1000, Loss: 0.0000
# Epoch 1/3, Batch 986/1000, Loss: 0.0000
# Epoch 1/3, Batch 987/1000, Loss: 0.0000
# Epoch 1/3, Batch 988/1000, Loss: 0.0000
# Epoch 1/3, Batch 989/1000, Loss: 0.0000
# Epoch 1/3, Batch 990/1000, Loss: 0.0000
# Epoch 1/3, Batch 991/1000, Loss: 0.0000
# Epoch 1/3, Batch 992/1000, Loss: 0.0000
# Epoch 1/3, Batch 993/1000, Loss: 0.0000
# Epoch 1/3, Batch 994/1000, Loss: 0.0000
# Epoch 1/3, Batch 995/1000, Loss: 0.0000
# Epoch 1/3, Batch 996/1000, Loss: 0.0000
# Epoch 1/3, Batch 997/1000, Loss: 0.0000
# Epoch 1/3, Batch 998/1000, Loss: 0.0000
# Epoch 1/3, Batch 999/1000, Loss: 0.0000
# Epoch 1/3, Average Loss: 0.0061
# Epoch 2/3, Batch 0/1000, Loss: 0.0000
# Epoch 2/3, Batch 1/1000, Loss: 0.0000
# Epoch 2/3, Batch 2/1000, Loss: 0.0000
# Epoch 2/3, Batch 3/1000, Loss: 0.0000
# Epoch 2/3, Batch 4/1000, Loss: 0.0000
# Epoch 2/3, Batch 5/1000, Loss: 0.0000
# Epoch 2/3, Batch 6/1000, Loss: 0.0000
# Epoch 2/3, Batch 7/1000, Loss: 0.0000
# Epoch 2/3, Batch 8/1000, Loss: 0.0000
# Epoch 2/3, Batch 9/1000, Loss: 0.0000
# Epoch 2/3, Batch 10/1000, Loss: 0.0000
# Epoch 2/3, Batch 11/1000, Loss: 0.0000
# Epoch 2/3, Batch 12/1000, Loss: 0.0000
# Epoch 2/3, Batch 13/1000, Loss: 0.0000
# Epoch 2/3, Batch 14/1000, Loss: 0.0000
# Epoch 2/3, Batch 15/1000, Loss: 0.0000
# Epoch 2/3, Batch 16/1000, Loss: 0.0000
# Epoch 2/3, Batch 17/1000, Loss: 0.0000
# Epoch 2/3, Batch 18/1000, Loss: 0.0000
# Epoch 2/3, Batch 19/1000, Loss: 0.0000
# Epoch 2/3, Batch 20/1000, Loss: 0.0000
# Epoch 2/3, Batch 21/1000, Loss: 0.0000
# Epoch 2/3, Batch 22/1000, Loss: 0.0000
# Epoch 2/3, Batch 23/1000, Loss: 0.0000
# Epoch 2/3, Batch 24/1000, Loss: 0.0000
# Epoch 2/3, Batch 25/1000, Loss: 0.0000
# Epoch 2/3, Batch 26/1000, Loss: 0.0000
# Epoch 2/3, Batch 27/1000, Loss: 0.0000
# Epoch 2/3, Batch 28/1000, Loss: 0.0000
# Epoch 2/3, Batch 29/1000, Loss: 0.0000
# Epoch 2/3, Batch 30/1000, Loss: 0.0000
# Epoch 2/3, Batch 31/1000, Loss: 0.0000
# Epoch 2/3, Batch 32/1000, Loss: 0.0000
# Epoch 2/3, Batch 33/1000, Loss: 0.0000
# Epoch 2/3, Batch 34/1000, Loss: 0.0000
# Epoch 2/3, Batch 35/1000, Loss: 0.0000
# Epoch 2/3, Batch 36/1000, Loss: 0.0000
# Epoch 2/3, Batch 37/1000, Loss: 0.0000
# Epoch 2/3, Batch 38/1000, Loss: 0.0000
# Epoch 2/3, Batch 39/1000, Loss: 0.0000
# Epoch 2/3, Batch 40/1000, Loss: 0.0000
# Epoch 2/3, Batch 41/1000, Loss: 0.0000
# Epoch 2/3, Batch 42/1000, Loss: 0.0000
# Epoch 2/3, Batch 43/1000, Loss: 0.0000
# Epoch 2/3, Batch 44/1000, Loss: 0.0000
# Epoch 2/3, Batch 45/1000, Loss: 0.0000
# Epoch 2/3, Batch 46/1000, Loss: 0.0000
# Epoch 2/3, Batch 47/1000, Loss: 0.0000
# Epoch 2/3, Batch 48/1000, Loss: 0.0000
# Epoch 2/3, Batch 49/1000, Loss: 0.0000
# Epoch 2/3, Batch 50/1000, Loss: 0.0000
# Epoch 2/3, Batch 51/1000, Loss: 0.0000
# Epoch 2/3, Batch 52/1000, Loss: 0.0000
# Epoch 2/3, Batch 53/1000, Loss: 0.0000
# Epoch 2/3, Batch 54/1000, Loss: 0.0000
# Epoch 2/3, Batch 55/1000, Loss: 0.0000
# Epoch 2/3, Batch 56/1000, Loss: 0.0000
# Epoch 2/3, Batch 57/1000, Loss: 0.0000
# Epoch 2/3, Batch 58/1000, Loss: 0.0000
# Epoch 2/3, Batch 59/1000, Loss: 0.0000
# Epoch 2/3, Batch 60/1000, Loss: 0.0000
# Epoch 2/3, Batch 61/1000, Loss: 0.0000
# Epoch 2/3, Batch 62/1000, Loss: 0.0000
# Epoch 2/3, Batch 63/1000, Loss: 0.0000
# Epoch 2/3, Batch 64/1000, Loss: 0.0000
# Epoch 2/3, Batch 65/1000, Loss: 0.0000
# Epoch 2/3, Batch 66/1000, Loss: 0.0000
# Epoch 2/3, Batch 67/1000, Loss: 0.0000
# Epoch 2/3, Batch 68/1000, Loss: 0.0000
# Epoch 2/3, Batch 69/1000, Loss: 0.0000
# Epoch 2/3, Batch 70/1000, Loss: 0.0000
# Epoch 2/3, Batch 71/1000, Loss: 0.0000
# Epoch 2/3, Batch 72/1000, Loss: 0.0000
# Epoch 2/3, Batch 73/1000, Loss: 0.0000
# Epoch 2/3, Batch 74/1000, Loss: 0.0000
# Epoch 2/3, Batch 75/1000, Loss: 0.0000
# Epoch 2/3, Batch 76/1000, Loss: 0.0000
# Epoch 2/3, Batch 77/1000, Loss: 0.0000
# Epoch 2/3, Batch 78/1000, Loss: 0.0000
# Epoch 2/3, Batch 79/1000, Loss: 0.0000
# Epoch 2/3, Batch 80/1000, Loss: 0.0000
# Epoch 2/3, Batch 81/1000, Loss: 0.0000
# Epoch 2/3, Batch 82/1000, Loss: 0.0000
# Epoch 2/3, Batch 83/1000, Loss: 0.0000
# Epoch 2/3, Batch 84/1000, Loss: 0.0000
# Epoch 2/3, Batch 85/1000, Loss: 0.0000
# Epoch 2/3, Batch 86/1000, Loss: 0.0000
# Epoch 2/3, Batch 87/1000, Loss: 0.0000
# Epoch 2/3, Batch 88/1000, Loss: 0.0000
# Epoch 2/3, Batch 89/1000, Loss: 0.0000
# Epoch 2/3, Batch 90/1000, Loss: 0.0000
# Epoch 2/3, Batch 91/1000, Loss: 0.0000
# Epoch 2/3, Batch 92/1000, Loss: 0.0000
# Epoch 2/3, Batch 93/1000, Loss: 0.0000
# Epoch 2/3, Batch 94/1000, Loss: 0.0000
# Epoch 2/3, Batch 95/1000, Loss: 0.0000
# Epoch 2/3, Batch 96/1000, Loss: 0.0000
# Epoch 2/3, Batch 97/1000, Loss: 0.0000
# Epoch 2/3, Batch 98/1000, Loss: 0.0000
# Epoch 2/3, Batch 99/1000, Loss: 0.0000
# Epoch 2/3, Batch 100/1000, Loss: 0.0000
# Epoch 2/3, Batch 101/1000, Loss: 0.0000
# Epoch 2/3, Batch 102/1000, Loss: 0.0000
# Epoch 2/3, Batch 103/1000, Loss: 0.0000
# Epoch 2/3, Batch 104/1000, Loss: 0.0000
# Epoch 2/3, Batch 105/1000, Loss: 0.0000
# Epoch 2/3, Batch 106/1000, Loss: 0.0000
# Epoch 2/3, Batch 107/1000, Loss: 0.0000
# Epoch 2/3, Batch 108/1000, Loss: 0.0000
# Epoch 2/3, Batch 109/1000, Loss: 0.0000
# Epoch 2/3, Batch 110/1000, Loss: 0.0000
# Epoch 2/3, Batch 111/1000, Loss: 0.0000
# Epoch 2/3, Batch 112/1000, Loss: 0.0000
# Epoch 2/3, Batch 113/1000, Loss: 0.0000
# Epoch 2/3, Batch 114/1000, Loss: 0.0000
# Epoch 2/3, Batch 115/1000, Loss: 0.0000
# Epoch 2/3, Batch 116/1000, Loss: 0.0000
# Epoch 2/3, Batch 117/1000, Loss: 0.0000
# Epoch 2/3, Batch 118/1000, Loss: 0.0000
# Epoch 2/3, Batch 119/1000, Loss: 0.0000
# Epoch 2/3, Batch 120/1000, Loss: 0.0000
# Epoch 2/3, Batch 121/1000, Loss: 0.0000
# Epoch 2/3, Batch 122/1000, Loss: 0.0000
# Epoch 2/3, Batch 123/1000, Loss: 0.0000
# Epoch 2/3, Batch 124/1000, Loss: 0.0000
# Epoch 2/3, Batch 125/1000, Loss: 0.0000
# Epoch 2/3, Batch 126/1000, Loss: 0.0000
# Epoch 2/3, Batch 127/1000, Loss: 0.0000
# Epoch 2/3, Batch 128/1000, Loss: 0.0000
# Epoch 2/3, Batch 129/1000, Loss: 0.0000
# Epoch 2/3, Batch 130/1000, Loss: 0.0000
# Epoch 2/3, Batch 131/1000, Loss: 0.0000
# Epoch 2/3, Batch 132/1000, Loss: 0.0000
# Epoch 2/3, Batch 133/1000, Loss: 0.0000
# Epoch 2/3, Batch 134/1000, Loss: 0.0000
# Epoch 2/3, Batch 135/1000, Loss: 0.0000
# Epoch 2/3, Batch 136/1000, Loss: 0.0000
# Epoch 2/3, Batch 137/1000, Loss: 0.0000
# Epoch 2/3, Batch 138/1000, Loss: 0.0000
# Epoch 2/3, Batch 139/1000, Loss: 0.0000
# Epoch 2/3, Batch 140/1000, Loss: 0.0000
# Epoch 2/3, Batch 141/1000, Loss: 0.0000
# Epoch 2/3, Batch 142/1000, Loss: 0.0000
# Epoch 2/3, Batch 143/1000, Loss: 0.0000
# Epoch 2/3, Batch 144/1000, Loss: 0.0000
# Epoch 2/3, Batch 145/1000, Loss: 0.0000
# Epoch 2/3, Batch 146/1000, Loss: 0.0000
# Epoch 2/3, Batch 147/1000, Loss: 0.0000
# Epoch 2/3, Batch 148/1000, Loss: 0.0000
# Epoch 2/3, Batch 149/1000, Loss: 0.0000
# Epoch 2/3, Batch 150/1000, Loss: 0.0000
# Epoch 2/3, Batch 151/1000, Loss: 0.0000
# Epoch 2/3, Batch 152/1000, Loss: 0.0000
# Epoch 2/3, Batch 153/1000, Loss: 0.0000
# Epoch 2/3, Batch 154/1000, Loss: 0.0000
# Epoch 2/3, Batch 155/1000, Loss: 0.0000
# Epoch 2/3, Batch 156/1000, Loss: 0.0000
# Epoch 2/3, Batch 157/1000, Loss: 0.0000
# Epoch 2/3, Batch 158/1000, Loss: 0.0000
# Epoch 2/3, Batch 159/1000, Loss: 0.0000
# Epoch 2/3, Batch 160/1000, Loss: 0.0000
# Epoch 2/3, Batch 161/1000, Loss: 0.0000
# Epoch 2/3, Batch 162/1000, Loss: 0.0000
# Epoch 2/3, Batch 163/1000, Loss: 0.0000
# Epoch 2/3, Batch 164/1000, Loss: 0.0000
# Epoch 2/3, Batch 165/1000, Loss: 0.0000
# Epoch 2/3, Batch 166/1000, Loss: 0.0000
# Epoch 2/3, Batch 167/1000, Loss: 0.0000
# Epoch 2/3, Batch 168/1000, Loss: 0.0000
# Epoch 2/3, Batch 169/1000, Loss: 0.0000
# Epoch 2/3, Batch 170/1000, Loss: 0.0000
# Epoch 2/3, Batch 171/1000, Loss: 0.0000
# Epoch 2/3, Batch 172/1000, Loss: 0.0000
# Epoch 2/3, Batch 173/1000, Loss: 0.0000
# Epoch 2/3, Batch 174/1000, Loss: 0.0000
# Epoch 2/3, Batch 175/1000, Loss: 0.0000
# Epoch 2/3, Batch 176/1000, Loss: 0.0000
# Epoch 2/3, Batch 177/1000, Loss: 0.0000
# Epoch 2/3, Batch 178/1000, Loss: 0.0000
# Epoch 2/3, Batch 179/1000, Loss: 0.0000
# Epoch 2/3, Batch 180/1000, Loss: 0.0000
# Epoch 2/3, Batch 181/1000, Loss: 0.0000
# Epoch 2/3, Batch 182/1000, Loss: 0.0000
# Epoch 2/3, Batch 183/1000, Loss: 0.0000
# Epoch 2/3, Batch 184/1000, Loss: 0.0000
# Epoch 2/3, Batch 185/1000, Loss: 0.0000
# Epoch 2/3, Batch 186/1000, Loss: 0.0000
# Epoch 2/3, Batch 187/1000, Loss: 0.0000
# Epoch 2/3, Batch 188/1000, Loss: 0.0000
# Epoch 2/3, Batch 189/1000, Loss: 0.0000
# Epoch 2/3, Batch 190/1000, Loss: 0.0000
# Epoch 2/3, Batch 191/1000, Loss: 0.0000
# Epoch 2/3, Batch 192/1000, Loss: 0.0000
# Epoch 2/3, Batch 193/1000, Loss: 0.0000
# Epoch 2/3, Batch 194/1000, Loss: 0.0000
# Epoch 2/3, Batch 195/1000, Loss: 0.0000
# Epoch 2/3, Batch 196/1000, Loss: 0.0000
# Epoch 2/3, Batch 197/1000, Loss: 0.0000
# Epoch 2/3, Batch 198/1000, Loss: 0.0000
# Epoch 2/3, Batch 199/1000, Loss: 0.0000
# Epoch 2/3, Batch 200/1000, Loss: 0.0000
# Epoch 2/3, Batch 201/1000, Loss: 0.0000
# Epoch 2/3, Batch 202/1000, Loss: 0.0000
# Epoch 2/3, Batch 203/1000, Loss: 0.0000
# ...
# Epoch 3/3, Batch 604/1000, Loss: 0.0000
# Epoch 3/3, Batch 605/1000, Loss: 0.0000
# Epoch 3/3, Batch 606/1000, Loss: 0.0000
# Epoch 3/3, Batch 607/1000, Loss: 0.0000
# Epoch 3/3, Batch 608/1000, Loss: 0.0000
# Epoch 3/3, Batch 609/1000, Loss: 0.0000
# Epoch 3/3, Batch 610/1000, Loss: 0.0000
# Epoch 3/3, Batch 611/1000, Loss: 0.0000
# Epoch 3/3, Batch 612/1000, Loss: 0.0000
# Epoch 3/3, Batch 613/1000, Loss: 0.0000
# Epoch 3/3, Batch 614/1000, Loss: 0.0000
# Epoch 3/3, Batch 615/1000, Loss: 0.0000
# Epoch 3/3, Batch 616/1000, Loss: 0.0000
# Epoch 3/3, Batch 617/1000, Loss: 0.0000
# Epoch 3/3, Batch 618/1000, Loss: 0.0000
# Epoch 3/3, Batch 619/1000, Loss: 0.0000
# Epoch 3/3, Batch 620/1000, Loss: 0.0000
# Epoch 3/3, Batch 621/1000, Loss: 0.0000
# Epoch 3/3, Batch 622/1000, Loss: 0.0000
# Epoch 3/3, Batch 623/1000, Loss: 0.0000
# Epoch 3/3, Batch 624/1000, Loss: 0.0000
# Epoch 3/3, Batch 625/1000, Loss: 0.0000
# Epoch 3/3, Batch 626/1000, Loss: 0.0000
# Epoch 3/3, Batch 627/1000, Loss: 0.0000
# Epoch 3/3, Batch 628/1000, Loss: 0.0000
# Epoch 3/3, Batch 629/1000, Loss: 0.0000
# Epoch 3/3, Batch 630/1000, Loss: 0.0000
# Epoch 3/3, Batch 631/1000, Loss: 0.0000
# Epoch 3/3, Batch 632/1000, Loss: 0.0000
# Epoch 3/3, Batch 633/1000, Loss: 0.0000
# Epoch 3/3, Batch 634/1000, Loss: 0.0000
# Epoch 3/3, Batch 635/1000, Loss: 0.0000
# Epoch 3/3, Batch 636/1000, Loss: 0.0000
# Epoch 3/3, Batch 637/1000, Loss: 0.0000
# Epoch 3/3, Batch 638/1000, Loss: 0.0000
# Epoch 3/3, Batch 639/1000, Loss: 0.0000
# Epoch 3/3, Batch 640/1000, Loss: 0.0000
# Epoch 3/3, Batch 641/1000, Loss: 0.0000
# Epoch 3/3, Batch 642/1000, Loss: 0.0000
# Epoch 3/3, Batch 643/1000, Loss: 0.0000
# Epoch 3/3, Batch 644/1000, Loss: 0.0000
# Epoch 3/3, Batch 645/1000, Loss: 0.0000
# Epoch 3/3, Batch 646/1000, Loss: 0.0000
# Epoch 3/3, Batch 647/1000, Loss: 0.0000
# Epoch 3/3, Batch 648/1000, Loss: 0.0000
# Epoch 3/3, Batch 649/1000, Loss: 0.0000
# Epoch 3/3, Batch 650/1000, Loss: 0.0000
# Epoch 3/3, Batch 651/1000, Loss: 0.0000
# Epoch 3/3, Batch 652/1000, Loss: 0.0000
# Epoch 3/3, Batch 653/1000, Loss: 0.0000
# Epoch 3/3, Batch 654/1000, Loss: 0.0000
# Epoch 3/3, Batch 655/1000, Loss: 0.0000
# Epoch 3/3, Batch 656/1000, Loss: 0.0000
# Epoch 3/3, Batch 657/1000, Loss: 0.0000
# Epoch 3/3, Batch 658/1000, Loss: 0.0000
# Epoch 3/3, Batch 659/1000, Loss: 0.0000
# Epoch 3/3, Batch 660/1000, Loss: 0.0000
# Epoch 3/3, Batch 661/1000, Loss: 0.0000
# Epoch 3/3, Batch 662/1000, Loss: 0.0000
# Epoch 3/3, Batch 663/1000, Loss: 0.0000
# Epoch 3/3, Batch 664/1000, Loss: 0.0000
# Epoch 3/3, Batch 665/1000, Loss: 0.0000
# Epoch 3/3, Batch 666/1000, Loss: 0.0000
# Epoch 3/3, Batch 667/1000, Loss: 0.0000
# Epoch 3/3, Batch 668/1000, Loss: 0.0000
# Epoch 3/3, Batch 669/1000, Loss: 0.0000
# Epoch 3/3, Batch 670/1000, Loss: 0.0000
# Epoch 3/3, Batch 671/1000, Loss: 0.0000
# Epoch 3/3, Batch 672/1000, Loss: 0.0000
# Epoch 3/3, Batch 673/1000, Loss: 0.0000
# Epoch 3/3, Batch 674/1000, Loss: 0.0000
# Epoch 3/3, Batch 675/1000, Loss: 0.0000
# Epoch 3/3, Batch 676/1000, Loss: 0.0000
# Epoch 3/3, Batch 677/1000, Loss: 0.0000
# Epoch 3/3, Batch 678/1000, Loss: 0.0000
# Epoch 3/3, Batch 679/1000, Loss: 0.0000
# Epoch 3/3, Batch 680/1000, Loss: 0.0000
# Epoch 3/3, Batch 681/1000, Loss: 0.0000
# Epoch 3/3, Batch 682/1000, Loss: 0.0000
# Epoch 3/3, Batch 683/1000, Loss: 0.0000
# Epoch 3/3, Batch 684/1000, Loss: 0.0000
# Epoch 3/3, Batch 685/1000, Loss: 0.0000
# Epoch 3/3, Batch 686/1000, Loss: 0.0000
# Epoch 3/3, Batch 687/1000, Loss: 0.0000
# Epoch 3/3, Batch 688/1000, Loss: 0.0000
# Epoch 3/3, Batch 689/1000, Loss: 0.0000
# Epoch 3/3, Batch 690/1000, Loss: 0.0000
# Epoch 3/3, Batch 691/1000, Loss: 0.0000
# Epoch 3/3, Batch 692/1000, Loss: 0.0000
# Epoch 3/3, Batch 693/1000, Loss: 0.0000
# Epoch 3/3, Batch 694/1000, Loss: 0.0000
# Epoch 3/3, Batch 695/1000, Loss: 0.0000
# Epoch 3/3, Batch 696/1000, Loss: 0.0000
# Epoch 3/3, Batch 697/1000, Loss: 0.0000
# Epoch 3/3, Batch 698/1000, Loss: 0.0000
# Epoch 3/3, Batch 699/1000, Loss: 0.0000
# Epoch 3/3, Batch 700/1000, Loss: 0.0000
# Epoch 3/3, Batch 701/1000, Loss: 0.0000
# Epoch 3/3, Batch 702/1000, Loss: 0.0000
# Epoch 3/3, Batch 703/1000, Loss: 0.0000
# Epoch 3/3, Batch 704/1000, Loss: 0.0000
# Epoch 3/3, Batch 705/1000, Loss: 0.0000
# Epoch 3/3, Batch 706/1000, Loss: 0.0000
# Epoch 3/3, Batch 707/1000, Loss: 0.0000
# Epoch 3/3, Batch 708/1000, Loss: 0.0000
# Epoch 3/3, Batch 709/1000, Loss: 0.0000
# Epoch 3/3, Batch 710/1000, Loss: 0.0000
# Epoch 3/3, Batch 711/1000, Loss: 0.0000
# Epoch 3/3, Batch 712/1000, Loss: 0.0000
# Epoch 3/3, Batch 713/1000, Loss: 0.0000
# Epoch 3/3, Batch 714/1000, Loss: 0.0000
# Epoch 3/3, Batch 715/1000, Loss: 0.0000
# Epoch 3/3, Batch 716/1000, Loss: 0.0000
# Epoch 3/3, Batch 717/1000, Loss: 0.0000
# Epoch 3/3, Batch 718/1000, Loss: 0.0000
# Epoch 3/3, Batch 719/1000, Loss: 0.0000
# Epoch 3/3, Batch 720/1000, Loss: 0.0000
# Epoch 3/3, Batch 721/1000, Loss: 0.0000
# Epoch 3/3, Batch 722/1000, Loss: 0.0000
# Epoch 3/3, Batch 723/1000, Loss: 0.0000
# Epoch 3/3, Batch 724/1000, Loss: 0.0000
# Epoch 3/3, Batch 725/1000, Loss: 0.0000
# Epoch 3/3, Batch 726/1000, Loss: 0.0000
# Epoch 3/3, Batch 727/1000, Loss: 0.0000
# Epoch 3/3, Batch 728/1000, Loss: 0.0000
# Epoch 3/3, Batch 729/1000, Loss: 0.0000
# Epoch 3/3, Batch 730/1000, Loss: 0.0000
# Epoch 3/3, Batch 731/1000, Loss: 0.0000
# Epoch 3/3, Batch 732/1000, Loss: 0.0000
# Epoch 3/3, Batch 733/1000, Loss: 0.0000
# Epoch 3/3, Batch 734/1000, Loss: 0.0000
# Epoch 3/3, Batch 735/1000, Loss: 0.0000
# Epoch 3/3, Batch 736/1000, Loss: 0.0000
# Epoch 3/3, Batch 737/1000, Loss: 0.0000
# Epoch 3/3, Batch 738/1000, Loss: 0.0000
# Epoch 3/3, Batch 739/1000, Loss: 0.0000
# Epoch 3/3, Batch 740/1000, Loss: 0.0000
# Epoch 3/3, Batch 741/1000, Loss: 0.0000
# Epoch 3/3, Batch 742/1000, Loss: 0.0000
# Epoch 3/3, Batch 743/1000, Loss: 0.0000
# Epoch 3/3, Batch 744/1000, Loss: 0.0000
# Epoch 3/3, Batch 745/1000, Loss: 0.0000
# Epoch 3/3, Batch 746/1000, Loss: 0.0000
# Epoch 3/3, Batch 747/1000, Loss: 0.0000
# Epoch 3/3, Batch 748/1000, Loss: 0.0000
# Epoch 3/3, Batch 749/1000, Loss: 0.0000
# Epoch 3/3, Batch 750/1000, Loss: 0.0000
# Epoch 3/3, Batch 751/1000, Loss: 0.0000
# Epoch 3/3, Batch 752/1000, Loss: 0.0000
# Epoch 3/3, Batch 753/1000, Loss: 0.0000
# Epoch 3/3, Batch 754/1000, Loss: 0.0000
# Epoch 3/3, Batch 755/1000, Loss: 0.0000
# Epoch 3/3, Batch 756/1000, Loss: 0.0000
# Epoch 3/3, Batch 757/1000, Loss: 0.0000
# Epoch 3/3, Batch 758/1000, Loss: 0.0000
# Epoch 3/3, Batch 759/1000, Loss: 0.0000
# Epoch 3/3, Batch 760/1000, Loss: 0.0000
# Epoch 3/3, Batch 761/1000, Loss: 0.0000
# Epoch 3/3, Batch 762/1000, Loss: 0.0000
# Epoch 3/3, Batch 763/1000, Loss: 0.0000
# Epoch 3/3, Batch 764/1000, Loss: 0.0000
# Epoch 3/3, Batch 765/1000, Loss: 0.0000
# Epoch 3/3, Batch 766/1000, Loss: 0.0000
# Epoch 3/3, Batch 767/1000, Loss: 0.0000
# Epoch 3/3, Batch 768/1000, Loss: 0.0000
# Epoch 3/3, Batch 769/1000, Loss: 0.0000
# Epoch 3/3, Batch 770/1000, Loss: 0.0000
# Epoch 3/3, Batch 771/1000, Loss: 0.0000
# Epoch 3/3, Batch 772/1000, Loss: 0.0000
# Epoch 3/3, Batch 773/1000, Loss: 0.0000
# Epoch 3/3, Batch 774/1000, Loss: 0.0000
# Epoch 3/3, Batch 775/1000, Loss: 0.0000
# Epoch 3/3, Batch 776/1000, Loss: 0.0000
# Epoch 3/3, Batch 777/1000, Loss: 0.0000
# Epoch 3/3, Batch 778/1000, Loss: 0.0000
# Epoch 3/3, Batch 779/1000, Loss: 0.0000
# Epoch 3/3, Batch 780/1000, Loss: 0.0000
# Epoch 3/3, Batch 781/1000, Loss: 0.0000
# Epoch 3/3, Batch 782/1000, Loss: 0.0000
# Epoch 3/3, Batch 783/1000, Loss: 0.0000
# Epoch 3/3, Batch 784/1000, Loss: 0.0000
# Epoch 3/3, Batch 785/1000, Loss: 0.0000
# Epoch 3/3, Batch 786/1000, Loss: 0.0000
# Epoch 3/3, Batch 787/1000, Loss: 0.0000
# Epoch 3/3, Batch 788/1000, Loss: 0.0000
# Epoch 3/3, Batch 789/1000, Loss: 0.0000
# Epoch 3/3, Batch 790/1000, Loss: 0.0000
# Epoch 3/3, Batch 791/1000, Loss: 0.0000
# Epoch 3/3, Batch 792/1000, Loss: 0.0000
# Epoch 3/3, Batch 793/1000, Loss: 0.0000
# Epoch 3/3, Batch 794/1000, Loss: 0.0000
# Epoch 3/3, Batch 795/1000, Loss: 0.0000
# Epoch 3/3, Batch 796/1000, Loss: 0.0000
# Epoch 3/3, Batch 797/1000, Loss: 0.0000
# Epoch 3/3, Batch 798/1000, Loss: 0.0000
# Epoch 3/3, Batch 799/1000, Loss: 0.0000
# Epoch 3/3, Batch 800/1000, Loss: 0.0000
# Epoch 3/3, Batch 801/1000, Loss: 0.0000
# Epoch 3/3, Batch 802/1000, Loss: 0.0000
# Epoch 3/3, Batch 803/1000, Loss: 0.0000
# Epoch 3/3, Batch 804/1000, Loss: 0.0000
# Epoch 3/3, Batch 805/1000, Loss: 0.0000
# Epoch 3/3, Batch 806/1000, Loss: 0.0000
# Epoch 3/3, Batch 807/1000, Loss: 0.0000
# Epoch 3/3, Batch 808/1000, Loss: 0.0000
# Epoch 3/3, Batch 809/1000, Loss: 0.0000
# Epoch 3/3, Batch 810/1000, Loss: 0.0000
# Epoch 3/3, Batch 811/1000, Loss: 0.0000
# Epoch 3/3, Batch 812/1000, Loss: 0.0000
# Epoch 3/3, Batch 813/1000, Loss: 0.0000
# Epoch 3/3, Batch 814/1000, Loss: 0.0000
# Epoch 3/3, Batch 815/1000, Loss: 0.0000
# Epoch 3/3, Batch 816/1000, Loss: 0.0000
# Epoch 3/3, Batch 817/1000, Loss: 0.0000
# Epoch 3/3, Batch 818/1000, Loss: 0.0000
# Epoch 3/3, Batch 819/1000, Loss: 0.0000
# Epoch 3/3, Batch 820/1000, Loss: 0.0000
# Epoch 3/3, Batch 821/1000, Loss: 0.0000
# Epoch 3/3, Batch 822/1000, Loss: 0.0000
# Epoch 3/3, Batch 823/1000, Loss: 0.0000
# Epoch 3/3, Batch 824/1000, Loss: 0.0000
# Epoch 3/3, Batch 825/1000, Loss: 0.0000
# Epoch 3/3, Batch 826/1000, Loss: 0.0000
# Epoch 3/3, Batch 827/1000, Loss: 0.0000
# Epoch 3/3, Batch 828/1000, Loss: 0.0000
# Epoch 3/3, Batch 829/1000, Loss: 0.0000
# Epoch 3/3, Batch 830/1000, Loss: 0.0000
# Epoch 3/3, Batch 831/1000, Loss: 0.0000
# Epoch 3/3, Batch 832/1000, Loss: 0.0000
# Epoch 3/3, Batch 833/1000, Loss: 0.0000
# Epoch 3/3, Batch 834/1000, Loss: 0.0000
# Epoch 3/3, Batch 835/1000, Loss: 0.0000
# Epoch 3/3, Batch 836/1000, Loss: 0.0000
# Epoch 3/3, Batch 837/1000, Loss: 0.0000
# Epoch 3/3, Batch 838/1000, Loss: 0.0000
# Epoch 3/3, Batch 839/1000, Loss: 0.0000
# Epoch 3/3, Batch 840/1000, Loss: 0.0000
# Epoch 3/3, Batch 841/1000, Loss: 0.0000
# Epoch 3/3, Batch 842/1000, Loss: 0.0000
# Epoch 3/3, Batch 843/1000, Loss: 0.0000
# Epoch 3/3, Batch 844/1000, Loss: 0.0000
# Epoch 3/3, Batch 845/1000, Loss: 0.0000
# Epoch 3/3, Batch 846/1000, Loss: 0.0000
# Epoch 3/3, Batch 847/1000, Loss: 0.0000
# Epoch 3/3, Batch 848/1000, Loss: 0.0000
# Epoch 3/3, Batch 849/1000, Loss: 0.0000
# Epoch 3/3, Batch 850/1000, Loss: 0.0000
# Epoch 3/3, Batch 851/1000, Loss: 0.0000
# Epoch 3/3, Batch 852/1000, Loss: 0.0000
# Epoch 3/3, Batch 853/1000, Loss: 0.0000
# Epoch 3/3, Batch 854/1000, Loss: 0.0000
# Epoch 3/3, Batch 855/1000, Loss: 0.0000
# Epoch 3/3, Batch 856/1000, Loss: 0.0000
# Epoch 3/3, Batch 857/1000, Loss: 0.0000
# Epoch 3/3, Batch 858/1000, Loss: 0.0000
# Epoch 3/3, Batch 859/1000, Loss: 0.0000
# Epoch 3/3, Batch 860/1000, Loss: 0.0000
# Epoch 3/3, Batch 861/1000, Loss: 0.0000
# Epoch 3/3, Batch 862/1000, Loss: 0.0000
# Epoch 3/3, Batch 863/1000, Loss: 0.0000
# Epoch 3/3, Batch 864/1000, Loss: 0.0000
# Epoch 3/3, Batch 865/1000, Loss: 0.0000
# Epoch 3/3, Batch 866/1000, Loss: 0.0000
# Epoch 3/3, Batch 867/1000, Loss: 0.0000
# Epoch 3/3, Batch 868/1000, Loss: 0.0000
# Epoch 3/3, Batch 869/1000, Loss: 0.0000
# Epoch 3/3, Batch 870/1000, Loss: 0.0000
# Epoch 3/3, Batch 871/1000, Loss: 0.0000
# Epoch 3/3, Batch 872/1000, Loss: 0.0000
# Epoch 3/3, Batch 873/1000, Loss: 0.0000
# Epoch 3/3, Batch 874/1000, Loss: 0.0000
# Epoch 3/3, Batch 875/1000, Loss: 0.0000
# Epoch 3/3, Batch 876/1000, Loss: 0.0000
# Epoch 3/3, Batch 877/1000, Loss: 0.0000
# Epoch 3/3, Batch 878/1000, Loss: 0.0000
# Epoch 3/3, Batch 879/1000, Loss: 0.0000
# Epoch 3/3, Batch 880/1000, Loss: 0.0000
# Epoch 3/3, Batch 881/1000, Loss: 0.0000
# Epoch 3/3, Batch 882/1000, Loss: 0.0000
# Epoch 3/3, Batch 883/1000, Loss: 0.0000
# Epoch 3/3, Batch 884/1000, Loss: 0.0000
# Epoch 3/3, Batch 885/1000, Loss: 0.0000
# Epoch 3/3, Batch 886/1000, Loss: 0.0000
# Epoch 3/3, Batch 887/1000, Loss: 0.0000
# Epoch 3/3, Batch 888/1000, Loss: 0.0000
# Epoch 3/3, Batch 889/1000, Loss: 0.0000
# Epoch 3/3, Batch 890/1000, Loss: 0.0000
# Epoch 3/3, Batch 891/1000, Loss: 0.0000
# Epoch 3/3, Batch 892/1000, Loss: 0.0000
# Epoch 3/3, Batch 893/1000, Loss: 0.0000
# Epoch 3/3, Batch 894/1000, Loss: 0.0000
# Epoch 3/3, Batch 895/1000, Loss: 0.0000
# Epoch 3/3, Batch 896/1000, Loss: 0.0000
# Epoch 3/3, Batch 897/1000, Loss: 0.0000
# Epoch 3/3, Batch 898/1000, Loss: 0.0000
# Epoch 3/3, Batch 899/1000, Loss: 0.0000
# Epoch 3/3, Batch 900/1000, Loss: 0.0000
# Epoch 3/3, Batch 901/1000, Loss: 0.0000
# Epoch 3/3, Batch 902/1000, Loss: 0.0000
# Epoch 3/3, Batch 903/1000, Loss: 0.0000
# Epoch 3/3, Batch 904/1000, Loss: 0.0000
# Epoch 3/3, Batch 905/1000, Loss: 0.0000
# Epoch 3/3, Batch 906/1000, Loss: 0.0000
# Epoch 3/3, Batch 907/1000, Loss: 0.0000
# Epoch 3/3, Batch 908/1000, Loss: 0.0000
# Epoch 3/3, Batch 909/1000, Loss: 0.0000
# Epoch 3/3, Batch 910/1000, Loss: 0.0000
# Epoch 3/3, Batch 911/1000, Loss: 0.0000
# Epoch 3/3, Batch 912/1000, Loss: 0.0000
# Epoch 3/3, Batch 913/1000, Loss: 0.0000
# Epoch 3/3, Batch 914/1000, Loss: 0.0000
# Epoch 3/3, Batch 915/1000, Loss: 0.0000
# Epoch 3/3, Batch 916/1000, Loss: 0.0000
# Epoch 3/3, Batch 917/1000, Loss: 0.0000
# Epoch 3/3, Batch 918/1000, Loss: 0.0000
# Epoch 3/3, Batch 919/1000, Loss: 0.0000
# Epoch 3/3, Batch 920/1000, Loss: 0.0000
# Epoch 3/3, Batch 921/1000, Loss: 0.0000
# Epoch 3/3, Batch 922/1000, Loss: 0.0000
# Epoch 3/3, Batch 923/1000, Loss: 0.0000
# Epoch 3/3, Batch 924/1000, Loss: 0.0000
# Epoch 3/3, Batch 925/1000, Loss: 0.0000
# Epoch 3/3, Batch 926/1000, Loss: 0.0000
# Epoch 3/3, Batch 927/1000, Loss: 0.0000
# Epoch 3/3, Batch 928/1000, Loss: 0.0000
# Epoch 3/3, Batch 929/1000, Loss: 0.0000
# Epoch 3/3, Batch 930/1000, Loss: 0.0000
# Epoch 3/3, Batch 931/1000, Loss: 0.0000
# Epoch 3/3, Batch 932/1000, Loss: 0.0000
# Epoch 3/3, Batch 933/1000, Loss: 0.0000
# Epoch 3/3, Batch 934/1000, Loss: 0.0000
# Epoch 3/3, Batch 935/1000, Loss: 0.0000
# Epoch 3/3, Batch 936/1000, Loss: 0.0000
# Epoch 3/3, Batch 937/1000, Loss: 0.0000
# Epoch 3/3, Batch 938/1000, Loss: 0.0000
# Epoch 3/3, Batch 939/1000, Loss: 0.0000
# Epoch 3/3, Batch 940/1000, Loss: 0.0000
# Epoch 3/3, Batch 941/1000, Loss: 0.0000
# Epoch 3/3, Batch 942/1000, Loss: 0.0000
# Epoch 3/3, Batch 943/1000, Loss: 0.0000
# Epoch 3/3, Batch 944/1000, Loss: 0.0000
# Epoch 3/3, Batch 945/1000, Loss: 0.0000
# Epoch 3/3, Batch 946/1000, Loss: 0.0000
# Epoch 3/3, Batch 947/1000, Loss: 0.0000
# Epoch 3/3, Batch 948/1000, Loss: 0.0000
# Epoch 3/3, Batch 949/1000, Loss: 0.0000
# Epoch 3/3, Batch 950/1000, Loss: 0.0000
# Epoch 3/3, Batch 951/1000, Loss: 0.0000
# Epoch 3/3, Batch 952/1000, Loss: 0.0000
# Epoch 3/3, Batch 953/1000, Loss: 0.0000
# Epoch 3/3, Batch 954/1000, Loss: 0.0000
# Epoch 3/3, Batch 955/1000, Loss: 0.0000
# Epoch 3/3, Batch 956/1000, Loss: 0.0000
# Epoch 3/3, Batch 957/1000, Loss: 0.0000
# Epoch 3/3, Batch 958/1000, Loss: 0.0000
# Epoch 3/3, Batch 959/1000, Loss: 0.0000
# Epoch 3/3, Batch 960/1000, Loss: 0.0000
# Epoch 3/3, Batch 961/1000, Loss: 0.0000
# Epoch 3/3, Batch 962/1000, Loss: 0.0000
# Epoch 3/3, Batch 963/1000, Loss: 0.0000
# Epoch 3/3, Batch 964/1000, Loss: 0.0000
# Epoch 3/3, Batch 965/1000, Loss: 0.0000
# Epoch 3/3, Batch 966/1000, Loss: 0.0000
# Epoch 3/3, Batch 967/1000, Loss: 0.0000
# Epoch 3/3, Batch 968/1000, Loss: 0.0000
# Epoch 3/3, Batch 969/1000, Loss: 0.0000
# Epoch 3/3, Batch 970/1000, Loss: 0.0000
# Epoch 3/3, Batch 971/1000, Loss: 0.0000
# Epoch 3/3, Batch 972/1000, Loss: 0.0000
# Epoch 3/3, Batch 973/1000, Loss: 0.0000
# Epoch 3/3, Batch 974/1000, Loss: 0.0000
# Epoch 3/3, Batch 975/1000, Loss: 0.0000
# Epoch 3/3, Batch 976/1000, Loss: 0.0000
# Epoch 3/3, Batch 977/1000, Loss: 0.0000
# Epoch 3/3, Batch 978/1000, Loss: 0.0000
# Epoch 3/3, Batch 979/1000, Loss: 0.0000
# Epoch 3/3, Batch 980/1000, Loss: 0.0000
# Epoch 3/3, Batch 981/1000, Loss: 0.0000
# Epoch 3/3, Batch 982/1000, Loss: 0.0000
# Epoch 3/3, Batch 983/1000, Loss: 0.0000
# Epoch 3/3, Batch 984/1000, Loss: 0.0000
# Epoch 3/3, Batch 985/1000, Loss: 0.0000
# Epoch 3/3, Batch 986/1000, Loss: 0.0000
# Epoch 3/3, Batch 987/1000, Loss: 0.0000
# Epoch 3/3, Batch 988/1000, Loss: 0.0000
# Epoch 3/3, Batch 989/1000, Loss: 0.0000
# Epoch 3/3, Batch 990/1000, Loss: 0.0000
# Epoch 3/3, Batch 991/1000, Loss: 0.0000
# Epoch 3/3, Batch 992/1000, Loss: 0.0000
# Epoch 3/3, Batch 993/1000, Loss: 0.0000
# Epoch 3/3, Batch 994/1000, Loss: 0.0000
# Epoch 3/3, Batch 995/1000, Loss: 0.0000
# Epoch 3/3, Batch 996/1000, Loss: 0.0000
# Epoch 3/3, Batch 997/1000, Loss: 0.0000
# Epoch 3/3, Batch 998/1000, Loss: 0.0000
# Epoch 3/3, Batch 999/1000, Loss: 0.0000
# Epoch 3/3, Average Loss: 0.0000
# Training completed in 244.73 seconds
#
# --- Evaluating LSTM Model ---
# Accuracy: 100.00%
# Inference time: 4.48 seconds

# %% [markdown]
# # TASK 4: Pre-trained Transformer

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import time

from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    pipeline
)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch, time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transformer_model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer_transformer = AutoTokenizer.from_pretrained(transformer_model_name)
model_transformer = AutoModelForSequenceClassification.from_pretrained(transformer_model_name).to(device)

sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model_transformer,
    tokenizer=tokenizer_transformer,
    device=0 if torch.cuda.is_available() else -1,
    truncation=True,
    max_length=512
)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
print("\n--- Evaluating Pre-trained Transformer Model ---")

def evaluate_transformer(texts, labels, pipeline_model):
    correct = 0
    total = 0
    start_time = time.time()

    for text, true_label in zip(texts, labels):

        # ✅ Force truncation at call-time (important)
        result = pipeline_model(
            text,
            truncation=True,
            max_length=512
        )[0]

        predicted_sentiment = result["label"]

        # Map 'POSITIVE' → 1, 'NEGATIVE' → 0
        predicted_class = 1 if predicted_sentiment == "POSITIVE" else 0

        if predicted_class == true_label:
            correct += 1

        total += 1

    inference_time = time.time() - start_time
    accuracy = 100 * correct / total

    print(f"Transformer Accuracy: {accuracy:.2f}%")
    print(f"Transformer Inference time: {inference_time:.2f} seconds")

    return accuracy, inference_time


# Run evaluation
transformer_accuracy, transformer_inference_time = evaluate_transformer(
    test_texts,
    test_labels,
    sentiment_pipeline
)
# Out:
# --- Evaluating Pre-trained Transformer Model ---
# Transformer Accuracy: 90.60%
# Transformer Inference time: 228.83 seconds

# %%
# Load transformer model (with safe truncation)
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transformer_model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer_transformer = AutoTokenizer.from_pretrained(transformer_model_name)
model_transformer = AutoModelForSequenceClassification.from_pretrained(transformer_model_name).to(device)

# ✅ Create pipeline (GPU if available)
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model_transformer,
    tokenizer=tokenizer_transformer,
    device=0 if torch.cuda.is_available() else -1
)

print("\n--- Evaluating Pre-trained Transformer Model ---")

def evaluate_transformer(texts, labels, pipeline_model):
    correct = 0
    total = 0
    start_time = time.time()

    for text, true_label in zip(texts, labels):
        # ✅ Force truncation at call-time to avoid >512 token crash
        result = pipeline_model(text, truncation=True, max_length=512)[0]
        predicted_sentiment = result["label"]

        # Map 'POSITIVE' -> 1, 'NEGATIVE' -> 0
        predicted_class = 1 if predicted_sentiment == "POSITIVE" else 0

        if predicted_class == int(true_label):
            correct += 1
        total += 1

    inference_time = time.time() - start_time
    accuracy = 100 * correct / total if total else 0.0

    print(f"Transformer Accuracy: {accuracy:.2f}%")
    print(f"Transformer Inference time: {inference_time:.2f} seconds")

    return accuracy, inference_time


# Run evaluation
transformer_accuracy, transformer_inference_time = evaluate_transformer(
    test_texts, test_labels, sentiment_pipeline
)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# --- Evaluating Pre-trained Transformer Model ---
# Transformer Accuracy: 90.60%
# Transformer Inference time: 228.13 seconds

# %% [markdown]
# # TASK 5: Model Comparison

# %%
import matplotlib.pyplot as plt
import torch

def compare_models():
    # Accuracy comparison
    models = ['LSTM', 'Transformer']
    accuracies = [lstm_accuracy, transformer_accuracy]

    plt.figure(figsize=(10, 5))
    plt.bar(models, accuracies, color=['blue', 'orange'])
    plt.title('Model Accuracy Comparison')
    plt.ylabel('Accuracy (%)')
    plt.ylim(0, 100)
    for i, v in enumerate(accuracies):
        plt.text(i, v + 1, f"{v:.2f}%", ha='center')
    plt.savefig('accuracy_comparison_simplified.png')
    plt.close() # Close plot to prevent display issues in some environments

    # Inference time comparison
    times = [lstm_inference_time, transformer_inference_time]

    plt.figure(figsize=(10, 5))
    plt.bar(models, times, color=['blue', 'orange'])
    plt.title('Inference Time Comparison')
    plt.ylabel('Time (seconds)')
    for i, v in enumerate(times):
        plt.text(i, v + 0.1, f"{v:.2f}s", ha='center')
    plt.savefig('time_comparison_simplified.png')
    plt.close()

    # Print comparison table
    print("\n--- Model Comparison Summary ---")
    print("-" * 60)
    print(f"{'Metric':<20} | {'LSTM':<15} | {'Transformer':<15}")
    print("-" * 60)
    print(f"{'Accuracy':<20} | {lstm_accuracy:<15.2f}% | {transformer_accuracy:<15.2f}%")
    print(f"{'Inference Time':<20} | {lstm_inference_time:<15.2f}s | {transformer_inference_time:<15.2f}s")
    print(f"{'Training Time':<20} | {lstm_train_time:<15.2f}s | {'N/A (pre-trained)':<15}")

    # Parameter count
    lstm_params = sum(p.numel() for p in lstm_model.parameters())
    transformer_params = sum(p.numel() for p in model_transformer.parameters())
    print(f"{'Parameters':<20} | {lstm_params:<15,d} | {transformer_params:<15,d}")
    print("-" * 60)

compare_models()

# Specific example comparison
def compare_specific_examples():
    sample_texts = [
        "This movie was absolutely fantastic! I loved every minute of it.",
        "The film was neither good nor bad, just mediocre overall.",
        "What a terrible waste of time and money. Worst movie ever."
    ]

    print("\n--- Example Predictions ---")
    print("-" * 80)
    print(f"{'Text':<40} | {'LSTM Prediction':<20} | {'Transformer Prediction':<20}")
    print("-" * 80)

    lstm_model.eval()
    for text in sample_texts:
        # LSTM prediction
        processed = process_text_hf(text, tokenizer, max_len).unsqueeze(0).to(device)
        with torch.no_grad():
            lstm_output = torch.sigmoid(lstm_model(processed)).item()
        lstm_sentiment = "Positive" if lstm_output > 0.5 else "Negative"
        lstm_confidence = max(lstm_output, 1 - lstm_output) * 100

        # Transformer prediction using the pipeline
        transformer_result = sentiment_pipeline(text)[0]
        transformer_sentiment = transformer_result['label']
        transformer_confidence = transformer_result['score'] * 100

        print(f"{text[:37] + '...':<40} | {lstm_sentiment} ({lstm_confidence:.1f}%) | {transformer_sentiment} ({transformer_confidence:.1f}%)")

    print("-" * 80)

compare_specific_examples()
# Out:
# --- Model Comparison Summary ---
# ------------------------------------------------------------
# Metric               | LSTM            | Transformer
# ------------------------------------------------------------
# Accuracy             | 100.00         % | 90.60          %
# Inference Time       | 4.48           s | 228.13         s
# Training Time        | 244.73         s | N/A (pre-trained)
# Parameters           | 3,683,241       | 66,955,010
# ------------------------------------------------------------
#
# --- Example Predictions ---
# --------------------------------------------------------------------------------
# Text                                     | LSTM Prediction      | Transformer Prediction
# --------------------------------------------------------------------------------
# This movie was absolutely fantastic! ... | Negative (100.0%) | POSITIVE (100.0%)
# The film was neither good nor bad, ju... | Negative (100.0%) | NEGATIVE (100.0%)
# What a terrible waste of time and mon... | Negative (100.0%) | NEGATIVE (100.0%)
# --------------------------------------------------------------------------------
